# %% [markdown]
# # Deliverable 2
# Breitzman wants:
# A table for the products
# A table for the metadata

# %%
import os
from enum import Enum
import csv
import sqlite3 as lite
from decimal import Decimal
from datetime import date, datetime, timedelta

# %%
FILE_PATHS = {
    'DB_TEAM_8' : './../0_SD_Team_8/store_team_8.db',
    'DB_TEAM_9' : './../0_SD_Team_9/grocery_store.db',
    'DB_TEAM_10' : './../0_SD_Team_10/grocery_team_10_v2.db',
    'PRODUCTS_CSV' : './../2_Product_Mapping/PRODUCTS_MAPPED.csv'
}

DATA_MART_PATH = './../A_Build_Data_Mart/Region_C_Data_Mart.db'

# %%
file_exists = os.path.isfile(DATA_MART_PATH)

if(file_exists):
    print(f'OK - \'{DATA_MART_PATH}\'')
else:
    print(f'MISSING - \'{DATA_MART_PATH}\'')
    raise SystemExit('\n' "ERROR!" '\n' "You are missing files!" '\n' "Read and Follow the Cell instructions provided.")
# Out:
# OK - './../A_Build_Data_Mart/Region_C_Data_Mart.db'

# %%
'''
    If I try to make db_options an inner class to db, 
        I get an error saying that the class is undefined.
'''
class db_options(Enum):
        DEFAULT = 0
        RETURN_RESULTS = 1
        PRINT_RESULTS = 2

class db:
    
    def __init__(self, name):
        self.name = rf"{name}"

    def connect(self):
        self.con = lite.connect(self.name)
        self.cur = self.con.cursor()

    def build_table(self, name):      
        self.execute_sql(f'DROP TABLE IF EXISTS {name}')
        self.execute_sql(TABLE_DEFINITIONS[name])
    
    def execute_sql(self, sql, options=db_options.DEFAULT):
        if (options.value & db_options.RETURN_RESULTS.value):
            results = self.cur.execute(sql).fetchall()
            return results
        elif (options.value & db_options.PRINT_RESULTS.value):
            results = self.cur.execute(sql).fetchall()
            for row in results:
                print(row)
        else:
            self.cur.execute(sql)

    def execute_sql_values(self, sql, values, options=db_options.DEFAULT):
        if (options.value & db_options.RETURN_RESULTS.value):
            results = self.cur.execute(sql, values).fetchall()
            return results
        elif (options.value & db_options.PRINT_RESULTS.value):
            results = self.cur.execute(sql, values).fetchall()
            for row in results:
                print(row)
        else:
            self.cur.execute(sql, values)


    def commit(self):
        self.con.commit()

    def close(self):
        self.con.commit()
        self.con.close()

# %%
DB_HANDLE = db(DATA_MART_PATH)

# %%
DB_HANDLE.connect()

results = DB_HANDLE.execute_sql('SELECT * FROM product ORDER BY ProductKey ASC', options=db_options.RETURN_RESULTS)

for row in results:
    print(row)

DB_HANDLE.close()
# Out:
# (5, 42085001, 'GoGurt Variety Pack', 6, 'Yogurt', 'Yogurt', 'Dairy', 'Food', '8 ct', 12, 'Yogurt', 'Yoplait', 'Rowan Warehouse', 2.99)
# (8, 42088001, 'Choice Cuts Poultry', 214, 'Pet Food', 'Pet Food', 'Household', 'Non-Consumable', '36 oz', 12, 'Pet Food', 'Whiskas', 'Rowan Warehouse', 4.99)
# (10, 42090001, 'Juice Red Grape', 30, 'Juice', 'Juice', 'Beverages', 'Drink', '64 oz', 12, 'Juice', 'Welchs', 'Rowan Warehouse', 4.79)
# (11, 42091001, 'Cereal Whole Grain Biscuit', 35, 'Cereal', 'Cereal', 'Breakfast Foods', 'Food', '15 oz', 12, 'Cereal', 'Weetabix', 'Rowan Warehouse', 6.99)
# (14, 42094001, 'Splash Berry Blend', 30, 'Juice', 'Juice', 'Beverages', 'Drink', '64 oz', 12, 'Juice', 'V8', 'Rowan Warehouse', 2.99)
# (15, 42095001, 'Splash Mango Peach', 30, 'Juice', 'Juice', 'Beverages', 'Drink', '64 oz', 12, 'Juice', 'V8', 'Rowan Warehouse', 2.99)
# (16, 42096001, 'V-Fusion Berry', 30, 'Juice', 'Juice', 'Beverages', 'Drink', '8 pkg', 12, 'Juice', 'V8', 'Rowan Warehouse', 3.49)
# (17, 42097001, 'V-Fusion Pomegranate Blueberry', 30, 'Juice', 'Juice', 'Beverages', 'Drink', '46 oz', 12, 'Juice', 'V8', 'Rowan Warehouse', 3.99)
# (18, 42098001, 'V-Fusion Refreshers Peach Strawberry', 30, 'Juice', 'Juice', 'Beverages', 'Drink', '46 oz', 12, 'Juice', 'V8', 'Rowan Warehouse', 3.49)
# (19, 42099001, 'Whole Grain Original Cereal', 35, 'Cereal', 'Cereal', 'Breakfast Foods', 'Food', '13 oz', 12, 'Cereal', 'Uncle Sam', 'Rowan Warehouse', 2.5)
# (21, 42101001, 'Orange Juice Some Pulp', 30, 'Juice', 'Juice', 'Beverages', 'Drink', '89 oz', 12, 'Juice', 'Tropicana', 'Rowan Warehouse', 7.29)
# (22, 42102001, 'Trop50 Calcium', 30, 'Juice', 'Juice', 'Beverages', 'Drink', '89 oz', 12, 'Juice', 'Tropicana', 'Rowan Warehouse', 7.29)
# (23, 42103001, 'Tri-State Almonds ', 1, 'Nuts', 'Nuts', 'Produce', 'Food', '15.5', 12, 'Nuts', 'Tri-State', 'Rowan Warehouse', 1.54)
# (24, 42104001, 'Tri-State Asparagus ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '14.8', 12, 'Fresh Vegetables', 'Tri-State', 'Rowan Warehouse', 0.78)
# (25, 42105001, 'Tri-State Baby Onion ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '11.8', 12, 'Fresh Vegetables', 'Tri-State', 'Rowan Warehouse', 2.62)
# (26, 42106001, 'Tri-State Beets ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '19.6', 12, 'Fresh Vegetables', 'Tri-State', 'Rowan Warehouse', 3.42)
# (27, 42107001, 'Tri-State Broccoli ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '8.3', 12, 'Fresh Vegetables', 'Tri-State', 'Rowan Warehouse', 1.34)
# (28, 42108001, 'Tri-State Canned Peanuts ', 1, 'Nuts', 'Nuts', 'Produce', 'Food', '18.2', 12, 'Nuts', 'Tri-State', 'Rowan Warehouse', 0.85)
# (29, 42109001, 'Tri-State Cantelope ', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '16', 12, 'Fresh Fruit', 'Tri-State', 'Rowan Warehouse', 2.57)
# (30, 42110001, 'Tri-State Cauliflower ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '5.63', 12, 'Fresh Vegetables', 'Tri-State', 'Rowan Warehouse', 0.81)
# (31, 42111001, 'Tri-State Corn on the Cob ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '10.6', 12, 'Fresh Vegetables', 'Tri-State', 'Rowan Warehouse', 2.8)
# (32, 42112001, 'Tri-State Dried Mushrooms ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '15.6', 12, 'Fresh Vegetables', 'Tri-State', 'Rowan Warehouse', 2.61)
# (33, 42113001, 'Tri-State Elephant Garlic ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '15.1', 12, 'Fresh Vegetables', 'Tri-State', 'Rowan Warehouse', 1.71)
# (34, 42114001, 'Tri-State Fancy Plums ', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '10.6', 12, 'Fresh Fruit', 'Tri-State', 'Rowan Warehouse', 2.44)
# (35, 42115001, 'Tri-State Firm Tofu ', 67, 'Tofu', 'Tofu', 'Produce', 'Food', '11.6', 12, 'Tofu', 'Tri-State', 'Rowan Warehouse', 1.66)
# (36, 42116001, 'Tri-State Fresh Lima Beans ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '17.7', 12, 'Fresh Vegetables', 'Tri-State', 'Rowan Warehouse', 2.43)
# (37, 42117001, 'Tri-State Fuji Apples ', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '11.1', 12, 'Fresh Fruit', 'Tri-State', 'Rowan Warehouse', 2.69)
# (38, 42118001, 'Tri-State Garlic ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '14.1', 12, 'Fresh Vegetables', 'Tri-State', 'Rowan Warehouse', 0.74)
# (39, 42119001, 'Tri-State Golden Delcious Apples ', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '4.61', 12, 'Fresh Fruit', 'Tri-State', 'Rowan Warehouse', 1.96)
# (40, 42120001, 'Tri-State Green Pepper ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '10', 12, 'Fresh Vegetables', 'Tri-State', 'Rowan Warehouse', 3.64)
# (41, 42121001, 'Tri-State Honey Dew ', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '7.61', 12, 'Fresh Fruit', 'Tri-State', 'Rowan Warehouse', 1.42)
# (42, 42122001, 'Tri-State Lemons ', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '16.1', 12, 'Fresh Fruit', 'Tri-State', 'Rowan Warehouse', 1.77)
# (43, 42123001, 'Tri-State Lettuce ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '5.65', 12, 'Fresh Vegetables', 'Tri-State', 'Rowan Warehouse', 3.17)
# (44, 42124001, 'Tri-State Limes ', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '12.6', 12, 'Fresh Fruit', 'Tri-State', 'Rowan Warehouse', 2.4)
# (45, 42125001, 'Tri-State Macintosh Apples ', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '20', 12, 'Fresh Fruit', 'Tri-State', 'Rowan Warehouse', 1.82)
# (46, 42126001, 'Tri-State Mandarin Oranges ', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '13.1', 12, 'Fresh Fruit', 'Tri-State', 'Rowan Warehouse', 2.95)
# (47, 42127001, 'Tri-State Mixed Nuts ', 1, 'Nuts', 'Nuts', 'Produce', 'Food', '7.68', 12, 'Nuts', 'Tri-State', 'Rowan Warehouse', 1.76)
# (48, 42128001, 'Tri-State Mushrooms ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '15.1', 12, 'Fresh Vegetables', 'Tri-State', 'Rowan Warehouse', 1.16)
# (49, 42129001, 'Tri-State New Potatos ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '14.5', 12, 'Fresh Vegetables', 'Tri-State', 'Rowan Warehouse', 0.67)
# (50, 42130001, 'Tri-State Onions ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '13.8', 12, 'Fresh Vegetables', 'Tri-State', 'Rowan Warehouse', 2.53)
# (51, 42131001, 'Tri-State Oranges ', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '7.1', 12, 'Fresh Fruit', 'Tri-State', 'Rowan Warehouse', 3.19)
# (52, 42132001, 'Tri-State Party Nuts ', 1, 'Nuts', 'Nuts', 'Produce', 'Food', '12.6', 12, 'Nuts', 'Tri-State', 'Rowan Warehouse', 2.63)
# (53, 42133001, 'Tri-State Peaches ', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '8.5', 12, 'Fresh Fruit', 'Tri-State', 'Rowan Warehouse', 2.56)
# (54, 42134001, 'Tri-State Plums ', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '7.36', 12, 'Fresh Fruit', 'Tri-State', 'Rowan Warehouse', 2.86)
# (55, 42135001, 'Tri-State Potatos ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '6.17', 12, 'Fresh Vegetables', 'Tri-State', 'Rowan Warehouse', 1.96)
# (56, 42136001, 'Tri-State Prepared Salad ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '4.65', 12, 'Fresh Vegetables', 'Tri-State', 'Rowan Warehouse', 2.5)
# (57, 42137001, 'Tri-State Red Delcious Apples ', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '11.6', 12, 'Fresh Fruit', 'Tri-State', 'Rowan Warehouse', 3.61)
# (58, 42138001, 'Tri-State Red Pepper ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '6.55', 12, 'Fresh Vegetables', 'Tri-State', 'Rowan Warehouse', 3.87)
# (59, 42139001, 'Tri-State Shitake Mushrooms ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '9.89', 12, 'Fresh Vegetables', 'Tri-State', 'Rowan Warehouse', 2.93)
# (60, 42140001, 'Tri-State Squash ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '11', 12, 'Fresh Vegetables', 'Tri-State', 'Rowan Warehouse', 1.55)
# (61, 42141001, 'Tri-State Summer Squash ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '17.2', 12, 'Fresh Vegetables', 'Tri-State', 'Rowan Warehouse', 0.55)
# (62, 42142001, 'Tri-State Sweet Onion ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '20.3', 12, 'Fresh Vegetables', 'Tri-State', 'Rowan Warehouse', 1.57)
# (63, 42143001, 'Tri-State Sweet Peas ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '18.8', 12, 'Fresh Vegetables', 'Tri-State', 'Rowan Warehouse', 3.58)
# (64, 42144001, 'Tri-State Tangerines ', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '14.6', 12, 'Fresh Fruit', 'Tri-State', 'Rowan Warehouse', 0.62)
# (65, 42145001, 'Tri-State Tomatos ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '18.6', 12, 'Fresh Vegetables', 'Tri-State', 'Rowan Warehouse', 2.21)
# (66, 42146001, 'Tri-State Walnuts ', 1, 'Nuts', 'Nuts', 'Produce', 'Food', '16.7', 12, 'Nuts', 'Tri-State', 'Rowan Warehouse', 0.88)
# (67, 42147001, 'Toucan Canned Mixed Fruit ', 3, 'Canned Fruit', 'Canned Fruit', 'Canned Products', 'Food', '15.8', 12, 'Canned Fruit', 'Toucan', 'Rowan Warehouse', 1.4)
# (68, 42148001, 'Toucan Canned Peaches ', 3, 'Canned Fruit', 'Canned Fruit', 'Canned Products', 'Food', '15.7', 12, 'Canned Fruit', 'Toucan', 'Rowan Warehouse', 1.38)
# (69, 42149001, 'Diapers Size 3', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '36 ct', 12, 'Diapers', 'Tippy Toes', 'Rowan Warehouse', 7.99)
# (70, 42150001, 'Diapers Size 3', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '84 ct', 12, 'Diapers', 'Tippy Toes', 'Rowan Warehouse', 14.99)
# (71, 42151001, 'Diapers Size 3', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '96 ct', 12, 'Diapers', 'Tippy Toes', 'Rowan Warehouse', 16.99)
# (72, 42152001, 'Diapers Size 4', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '31 ct', 12, 'Diapers', 'Tippy Toes', 'Rowan Warehouse', 7.99)
# (73, 42153001, 'Diapers Size 4', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '72 ct', 12, 'Diapers', 'Tippy Toes', 'Rowan Warehouse', 14.99)
# (74, 42154001, 'Diapers Size 5', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '27 ct', 12, 'Diapers', 'Tippy Toes', 'Rowan Warehouse', 7.99)
# (75, 42155001, 'Diapers Size 5', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '70 ct', 12, 'Diapers', 'Tippy Toes', 'Rowan Warehouse', 16.99)
# (76, 42156001, 'Tip Top Lox ', 24, 'Fresh Fish', 'Fresh Fish', 'Seafood', 'Food', '11.1', 12, 'Fresh Fish', 'Tip Top', 'Rowan Warehouse', 0.79)
# (77, 42157001, 'Thresher Malted Milk Balls ', 36, 'Chocolate Candy', 'Chocolate Candy', 'Snacks', 'Food', '8.3', 12, 'Chocolate Candy', 'Thresher', 'Rowan Warehouse', 1.58)
# (78, 42158001, 'Thresher Mint Chocolate Bar ', 36, 'Chocolate Candy', 'Chocolate Candy', 'Snacks', 'Food', '17.8', 12, 'Chocolate Candy', 'Thresher', 'Rowan Warehouse', 1.71)
# (79, 42159001, 'Thresher Mints ', 38, 'Hard Candy', 'Hard Candy', 'Snacks', 'Food', '5.19', 12, 'Hard Candy', 'Thresher', 'Rowan Warehouse', 1.81)
# (80, 42160001, 'Thresher Semi-Sweet Chocolate Bar ', 36, 'Chocolate Candy', 'Chocolate Candy', 'Snacks', 'Food', '17.7', 12, 'Chocolate Candy', 'Thresher', 'Rowan Warehouse', 1.87)
# (81, 42161001, 'Thresher Spicy Mints ', 38, 'Hard Candy', 'Hard Candy', 'Snacks', 'Food', '8.1', 12, 'Hard Candy', 'Thresher', 'Rowan Warehouse', 3.65)
# (82, 42162001, 'Thresher Tasty Candy Bar ', 36, 'Chocolate Candy', 'Chocolate Candy', 'Snacks', 'Food', '16.5', 12, 'Chocolate Candy', 'Thresher', 'Rowan Warehouse', 3.44)
# (83, 42163001, 'Thresher White Chocolate Bar ', 36, 'Chocolate Candy', 'Chocolate Candy', 'Snacks', 'Food', '9.5', 12, 'Chocolate Candy', 'Thresher', 'Rowan Warehouse', 2.49)
# (105, 42185001, 'Tell Tale Almonds ', 1, 'Nuts', 'Nuts', 'Produce', 'Food', '8.5', 12, 'Nuts', 'Tell Tale', 'Rowan Warehouse', 3.68)
# (106, 42186001, 'Tell Tale Asparagus ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '6.35', 12, 'Fresh Vegetables', 'Tell Tale', 'Rowan Warehouse', 3.64)
# (107, 42187001, 'Tell Tale Baby Onion ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '14', 12, 'Fresh Vegetables', 'Tell Tale', 'Rowan Warehouse', 2.66)
# (108, 42188001, 'Tell Tale Beets ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '6.09', 12, 'Fresh Vegetables', 'Tell Tale', 'Rowan Warehouse', 2.6)
# (109, 42189001, 'Tell Tale Broccoli ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '17.8', 12, 'Fresh Vegetables', 'Tell Tale', 'Rowan Warehouse', 1.81)
# (110, 42190001, 'Tell Tale Canned Peanuts ', 1, 'Nuts', 'Nuts', 'Produce', 'Food', '6.86', 12, 'Nuts', 'Tell Tale', 'Rowan Warehouse', 3.4)
# (111, 42191001, 'Tell Tale Cantelope ', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '15.1', 12, 'Fresh Fruit', 'Tell Tale', 'Rowan Warehouse', 3.82)
# (112, 42192001, 'Tell Tale Cauliflower ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '13.6', 12, 'Fresh Vegetables', 'Tell Tale', 'Rowan Warehouse', 1.87)
# (113, 42193001, 'Tell Tale Corn on the Cob ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '10', 12, 'Fresh Vegetables', 'Tell Tale', 'Rowan Warehouse', 1.94)
# (114, 42194001, 'Tell Tale Dried Mushrooms ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '15.1', 12, 'Fresh Vegetables', 'Tell Tale', 'Rowan Warehouse', 1.45)
# (115, 42195001, 'Tell Tale Elephant Garlic ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '5.42', 12, 'Fresh Vegetables', 'Tell Tale', 'Rowan Warehouse', 2.64)
# (116, 42196001, 'Tell Tale Fancy Plums ', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '19', 12, 'Fresh Fruit', 'Tell Tale', 'Rowan Warehouse', 0.68)
# (117, 42197001, 'Tell Tale Firm Tofu ', 67, 'Tofu', 'Tofu', 'Produce', 'Food', '16.1', 12, 'Tofu', 'Tell Tale', 'Rowan Warehouse', 1.67)
# (118, 42198001, 'Tell Tale Fresh Lima Beans ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '18.1', 12, 'Fresh Vegetables', 'Tell Tale', 'Rowan Warehouse', 3.17)
# (119, 42199001, 'Tell Tale Fuji Apples ', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '6.47', 12, 'Fresh Fruit', 'Tell Tale', 'Rowan Warehouse', 3.63)
# (120, 42200001, 'Tell Tale Garlic ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '6.22', 12, 'Fresh Vegetables', 'Tell Tale', 'Rowan Warehouse', 1.17)
# (121, 42201001, 'Tell Tale Golden Delcious Apples ', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '11.8', 12, 'Fresh Fruit', 'Tell Tale', 'Rowan Warehouse', 3.79)
# (122, 42202001, 'Tell Tale Green Pepper ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '11.3', 12, 'Fresh Vegetables', 'Tell Tale', 'Rowan Warehouse', 1.65)
# (123, 42203001, 'Tell Tale Honey Dew ', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '6.28', 12, 'Fresh Fruit', 'Tell Tale', 'Rowan Warehouse', 2.8)
# (124, 42204001, 'Tell Tale Lemons ', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '7.32', 12, 'Fresh Fruit', 'Tell Tale', 'Rowan Warehouse', 0.61)
# (125, 42205001, 'Tell Tale Lettuce ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '19.2', 12, 'Fresh Vegetables', 'Tell Tale', 'Rowan Warehouse', 1.77)
# (126, 42206001, 'Tell Tale Limes ', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '11.6', 12, 'Fresh Fruit', 'Tell Tale', 'Rowan Warehouse', 1.84)
# (127, 42207001, 'Tell Tale Macintosh Apples ', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '18.3', 12, 'Fresh Fruit', 'Tell Tale', 'Rowan Warehouse', 2.53)
# (128, 42208001, 'Tell Tale Mandarin Oranges ', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '19.7', 12, 'Fresh Fruit', 'Tell Tale', 'Rowan Warehouse', 1.91)
# (129, 42209001, 'Tell Tale Mixed Nuts ', 1, 'Nuts', 'Nuts', 'Produce', 'Food', '19.7', 12, 'Nuts', 'Tell Tale', 'Rowan Warehouse', 1.85)
# (130, 42210001, 'Tell Tale Mushrooms ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '11.8', 12, 'Fresh Vegetables', 'Tell Tale', 'Rowan Warehouse', 2.96)
# (131, 42211001, 'Tell Tale New Potatos ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '12.8', 12, 'Fresh Vegetables', 'Tell Tale', 'Rowan Warehouse', 1.14)
# (132, 42212001, 'Tell Tale Onions ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '13.3', 12, 'Fresh Vegetables', 'Tell Tale', 'Rowan Warehouse', 2.41)
# (133, 42213001, 'Tell Tale Oranges ', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '9.3', 12, 'Fresh Fruit', 'Tell Tale', 'Rowan Warehouse', 1.72)
# (134, 42214001, 'Tell Tale Party Nuts ', 1, 'Nuts', 'Nuts', 'Produce', 'Food', '9.3', 12, 'Nuts', 'Tell Tale', 'Rowan Warehouse', 2.85)
# (135, 42215001, 'Tell Tale Peaches ', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '10', 12, 'Fresh Fruit', 'Tell Tale', 'Rowan Warehouse', 0.58)
# (136, 42216001, 'Tell Tale Plums ', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '7.85', 12, 'Fresh Fruit', 'Tell Tale', 'Rowan Warehouse', 2.74)
# (137, 42217001, 'Tell Tale Potatos ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '10.1', 12, 'Fresh Vegetables', 'Tell Tale', 'Rowan Warehouse', 0.84)
# (138, 42218001, 'Tell Tale Prepared Salad ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '7.77', 12, 'Fresh Vegetables', 'Tell Tale', 'Rowan Warehouse', 2.59)
# (139, 42219001, 'Tell Tale Red Delcious Apples ', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '18.8', 12, 'Fresh Fruit', 'Tell Tale', 'Rowan Warehouse', 1.9)
# (140, 42220001, 'Tell Tale Red Pepper ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '6.02', 12, 'Fresh Vegetables', 'Tell Tale', 'Rowan Warehouse', 1.93)
# (141, 42221001, 'Tell Tale Shitake Mushrooms ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '18.6', 12, 'Fresh Vegetables', 'Tell Tale', 'Rowan Warehouse', 3.51)
# (142, 42222001, 'Tell Tale Squash ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '20.2', 12, 'Fresh Vegetables', 'Tell Tale', 'Rowan Warehouse', 1.86)
# (143, 42223001, 'Tell Tale Summer Squash ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '16.7', 12, 'Fresh Vegetables', 'Tell Tale', 'Rowan Warehouse', 0.73)
# (144, 42224001, 'Tell Tale Sweet Onion ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '11.5', 12, 'Fresh Vegetables', 'Tell Tale', 'Rowan Warehouse', 1.36)
# (145, 42225001, 'Tell Tale Sweet Peas ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '12.5', 12, 'Fresh Vegetables', 'Tell Tale', 'Rowan Warehouse', 2.19)
# (146, 42226001, 'Tell Tale Tangerines ', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '11.8', 12, 'Fresh Fruit', 'Tell Tale', 'Rowan Warehouse', 1.74)
# (147, 42227001, 'Tell Tale Tomatos ', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '10.8', 12, 'Fresh Vegetables', 'Tell Tale', 'Rowan Warehouse', 2.55)
# (148, 42228001, 'Tell Tale Walnuts ', 1, 'Nuts', 'Nuts', 'Produce', 'Food', '13.6', 12, 'Nuts', 'Tell Tale', 'Rowan Warehouse', 1.63)
# (165, 42245001, 'Swell Canned Mixed Fruit ', 3, 'Canned Fruit', 'Canned Fruit', 'Canned Products', 'Food', '7.61', 12, 'Canned Fruit', 'Swell', 'Rowan Warehouse', 2.34)
# (166, 42246001, 'Swell Canned Peaches ', 3, 'Canned Fruit', 'Canned Fruit', 'Canned Products', 'Food', '12.3', 12, 'Canned Fruit', 'Swell', 'Rowan Warehouse', 1.63)
# (167, 42247001, 'Super Brown Sugar ', 50, 'Sugar', 'Sugar', 'Baking Goods', 'Food', '7.25', 12, 'Sugar', 'Super', 'Rowan Warehouse', 1.42)
# (168, 42248001, 'Super Canola Oil ', 49, 'Cooking Oil', 'Cooking Oil', 'Baking Goods', 'Food', '7.89', 12, 'Cooking Oil', 'Super', 'Rowan Warehouse', 1.32)
# (169, 42249001, 'Super Chunky Peanut Butter ', 53, 'Peanut Butter', 'Peanut Butter', 'Baking Goods', 'Food', '5.71', 12, 'Peanut Butter', 'Super', 'Rowan Warehouse', 0.99)
# (170, 42250001, 'Super Corn Oil ', 49, 'Cooking Oil', 'Cooking Oil', 'Baking Goods', 'Food', '5.63', 12, 'Cooking Oil', 'Super', 'Rowan Warehouse', 1.81)
# (171, 42251001, 'Super Creamy Peanut Butter ', 53, 'Peanut Butter', 'Peanut Butter', 'Baking Goods', 'Food', '15.2', 12, 'Peanut Butter', 'Super', 'Rowan Warehouse', 1.48)
# (172, 42252001, 'Super Extra Chunky Peanut Butter ', 53, 'Peanut Butter', 'Peanut Butter', 'Baking Goods', 'Food', '17.7', 12, 'Peanut Butter', 'Super', 'Rowan Warehouse', 3.62)
# (173, 42253001, 'Super Oregano ', 4, 'Spices', 'Spices', 'Baking Goods', 'Food', '11.6', 12, 'Spices', 'Super', 'Rowan Warehouse', 3.45)
# (174, 42254001, 'Super Pepper ', 4, 'Spices', 'Spices', 'Baking Goods', 'Food', '15.7', 12, 'Spices', 'Super', 'Rowan Warehouse', 2.83)
# (175, 42255001, 'Super Salt ', 4, 'Spices', 'Spices', 'Baking Goods', 'Food', '14.7', 12, 'Spices', 'Super', 'Rowan Warehouse', 2.94)
# (176, 42256001, 'Super Sesame Oil ', 49, 'Cooking Oil', 'Cooking Oil', 'Baking Goods', 'Food', '14.5', 12, 'Cooking Oil', 'Super', 'Rowan Warehouse', 2.73)
# (177, 42257001, 'Super Vegetable Oil ', 49, 'Cooking Oil', 'Cooking Oil', 'Baking Goods', 'Food', '7.23', 12, 'Cooking Oil', 'Super', 'Rowan Warehouse', 2.22)
# (178, 42258001, 'Super White Sugar ', 50, 'Sugar', 'Sugar', 'Baking Goods', 'Food', '10.6', 12, 'Sugar', 'Super', 'Rowan Warehouse', 1.56)
# (181, 42261001, 'Sunset Room Freshener ', 20, 'Deodorizers', 'Deodorizers', 'Household', 'Non-Consumable', '13.6', 12, 'Deodorizers', 'Sunset', 'Rowan Warehouse', 2.44)
# (193, 42273001, 'Steady 200 MG Acetominifen ', 72, 'Acetominifen', 'Acetominifen', 'Health and Hygiene', 'Non-Consumable', '4.32', 12, 'Acetominifen', 'Steady', 'Rowan Warehouse', 1.53)
# (194, 42274001, 'Steady 200 MG Ibuprofen ', 71, 'Ibuprofen', 'Ibuprofen', 'Health and Hygiene', 'Non-Consumable', '9.8', 12, 'Ibuprofen', 'Steady', 'Rowan Warehouse', 2.83)
# (195, 42275001, 'Steady Buffered Aspirin ', 70, 'Aspirin', 'Aspirin', 'Health and Hygiene', 'Non-Consumable', '18.1', 12, 'Aspirin', 'Steady', 'Rowan Warehouse', 1.42)
# (196, 42276001, 'Steady Childrens Aspirin ', 70, 'Aspirin', 'Aspirin', 'Health and Hygiene', 'Non-Consumable', '8.8', 12, 'Aspirin', 'Steady', 'Rowan Warehouse', 1.74)
# (197, 42277001, 'Steady Mint Mouthwash ', 74, 'Mouthwash', 'Mouthwash', 'Health and Hygiene', 'Non-Consumable', '20.1', 12, 'Mouthwash', 'Steady', 'Rowan Warehouse', 2.24)
# (235, 42315001, 'Peanut Butter Crunchy', 53, 'Peanut Butter', 'Peanut Butter', 'Baking Goods', 'Food', '28 oz', 12, 'Peanut Butter', 'Skippy', 'Rowan Warehouse', 3.99)
# (236, 42316001, 'Peanut Butter Smooth', 53, 'Peanut Butter', 'Peanut Butter', 'Baking Goods', 'Food', '28 oz', 12, 'Peanut Butter', 'Skippy', 'Rowan Warehouse', 3.99)
# (240, 42320001, 'Ship Shape Extra Lean Hamburger ', 65, 'Hamburger', 'Hamburger', 'Meat', 'Food', '11.3', 12, 'Hamburger', 'Ship Shape', 'Rowan Warehouse', 2.97)
# (241, 42321001, 'Ship Shape Seasoned Hamburger ', 65, 'Hamburger', 'Hamburger', 'Meat', 'Food', '6.26', 12, 'Hamburger', 'Ship Shape', 'Rowan Warehouse', 1.75)
# (242, 42322001, 'Shady Lake Rice Medly ', 57, 'Rice', 'Rice', 'Starchy Foods', 'Food', '16.6', 12, 'Rice', 'Shady Lake', 'Rowan Warehouse', 0.7)
# (243, 42323001, 'Shady Lake Thai Rice ', 57, 'Rice', 'Rice', 'Starchy Foods', 'Food', '8', 12, 'Rice', 'Shady Lake', 'Rowan Warehouse', 2.81)
# (256, 42336001, 'Bran Flakes Cereal', 35, 'Cereal', 'Cereal', 'Breakfast Foods', 'Food', '17.3 oz', 12, 'Cereal', 'Safeway Kitchens', 'Rowan Warehouse', 2.49)
# (266, 42346001, 'Corn Flakes Cereal', 35, 'Cereal', 'Cereal', 'Breakfast Foods', 'Food', '18 oz', 12, 'Cereal', 'Safeway Kitchens', 'Rowan Warehouse', 2.49)
# (267, 42347001, 'Crispy Rice Cereal', 35, 'Cereal', 'Cereal', 'Breakfast Foods', 'Food', '12 oz', 12, 'Cereal', 'Safeway Kitchens', 'Rowan Warehouse', 2.19)
# (268, 42348001, 'Honey Nut Toasted Oats Cereal', 35, 'Cereal', 'Cereal', 'Breakfast Foods', 'Food', '12.25 oz', 12, 'Cereal', 'Safeway Kitchens', 'Rowan Warehouse', 2.19)
# (275, 42355001, '1.00% Milk', 76, 'Milk', 'Milk', 'Dairy', 'Drink', '1 gal', 12, 'Milk', 'Rowan Dairy', 'Rowan Dairy', 3.69)
# (276, 42356001, '1.00% Milk', 76, 'Milk', 'Milk', 'Dairy', 'Drink', '1/2 gal', 12, 'Milk', 'Rowan Dairy', 'Rowan Dairy', 1.89)
# (277, 42357001, '2.00% Milk', 76, 'Milk', 'Milk', 'Dairy', 'Drink', '1 gal', 12, 'Milk', 'Rowan Dairy', 'Rowan Dairy', 3.69)
# (278, 42358001, '2.00% Milk', 76, 'Milk', 'Milk', 'Dairy', 'Drink', '1/2 gal', 12, 'Milk', 'Rowan Dairy', 'Rowan Dairy', 1.89)
# (279, 42359001, 'Whole Milk Milk', 76, 'Milk', 'Milk', 'Dairy', 'Drink', '1 gal', 12, 'Milk', 'Rowan Dairy', 'Rowan Dairy', 3.69)
# (280, 42360001, 'Whole Milk Milk', 76, 'Milk', 'Milk', 'Dairy', 'Drink', '1/2 gal', 12, 'Milk', 'Rowan Dairy', 'Rowan Dairy', 1.89)
# (281, 42361001, 'Cola Soda', 19, 'Soda', 'Soda', 'Beverages', 'Drink', '67.6 oz', 12, 'Soda', 'Rowan Brand', 'Rowan Warehouse', 0.99)
# (287, 42367001, 'Red Wing Room Freshener ', 20, 'Deodorizers', 'Deodorizers', 'Household', 'Non-Consumable', '13.1', 12, 'Deodorizers', 'Red Wing', 'Rowan Warehouse', 2.95)
# (289, 42369001, 'Red Spade Beef Bologna ', 91, 'Bologna', 'Bologna', 'Deli', 'Food', '9.3', 12, 'Bologna', 'Red Spade', 'Rowan Warehouse', 3.76)
# (290, 42370001, 'Red Spade Chicken Hot Dogs ', 81, 'Hot Dogs', 'Hot Dogs', 'Deli', 'Food', '18.2', 12, 'Hot Dogs', 'Red Spade', 'Rowan Warehouse', 2.95)
# (291, 42371001, 'Red Spade Cole Slaw ', 16, 'Deli Salads', 'Deli Salads', 'Deli', 'Food', '6.82', 12, 'Deli Salads', 'Red Spade', 'Rowan Warehouse', 0.97)
# (292, 42372001, 'Red Spade Corned Beef ', 8, 'Deli Meats', 'Deli Meats', 'Deli', 'Food', '17.2', 12, 'Deli Meats', 'Red Spade', 'Rowan Warehouse', 2.74)
# (293, 42373001, 'Red Spade Foot-Long Hot Dogs ', 81, 'Hot Dogs', 'Hot Dogs', 'Deli', 'Food', '14', 12, 'Hot Dogs', 'Red Spade', 'Rowan Warehouse', 3.56)
# (294, 42374001, 'Red Spade Low Fat Bologna ', 91, 'Bologna', 'Bologna', 'Deli', 'Food', '8.89', 12, 'Bologna', 'Red Spade', 'Rowan Warehouse', 3.44)
# (295, 42375001, 'Red Spade Low Fat Cole Slaw ', 16, 'Deli Salads', 'Deli Salads', 'Deli', 'Food', '14.7', 12, 'Deli Salads', 'Red Spade', 'Rowan Warehouse', 3.1)
# (296, 42376001, 'Red Spade Pimento Loaf ', 91, 'Bologna', 'Bologna', 'Deli', 'Food', '12.1', 12, 'Bologna', 'Red Spade', 'Rowan Warehouse', 1.61)
# (297, 42377001, 'Red Spade Potato Salad ', 16, 'Deli Salads', 'Deli Salads', 'Deli', 'Food', '14.8', 12, 'Deli Salads', 'Red Spade', 'Rowan Warehouse', 0.68)
# (298, 42378001, 'Red Spade Roasted Chicken ', 77, 'Fresh Chicken', 'Fresh Chicken', 'Deli', 'Food', '20.7', 12, 'Fresh Chicken', 'Red Spade', 'Rowan Warehouse', 2.76)
# (299, 42379001, 'Red Spade Sliced Chicken ', 8, 'Deli Meats', 'Deli Meats', 'Deli', 'Food', '17.1', 12, 'Deli Meats', 'Red Spade', 'Rowan Warehouse', 1.69)
# (300, 42380001, 'Red Spade Sliced Ham ', 8, 'Deli Meats', 'Deli Meats', 'Deli', 'Food', '5.13', 12, 'Deli Meats', 'Red Spade', 'Rowan Warehouse', 1.57)
# (301, 42381001, 'Red Spade Sliced Turkey ', 8, 'Deli Meats', 'Deli Meats', 'Deli', 'Food', '16.1', 12, 'Deli Meats', 'Red Spade', 'Rowan Warehouse', 2.33)
# (302, 42382001, 'Red Spade Turkey Hot Dogs ', 81, 'Hot Dogs', 'Hot Dogs', 'Deli', 'Food', '4.15', 12, 'Hot Dogs', 'Red Spade', 'Rowan Warehouse', 1.86)
# (305, 42385001, 'Quick Extra Lean Hamburger ', 65, 'Hamburger', 'Hamburger', 'Meat', 'Food', '17.8', 12, 'Hamburger', 'Quick', 'Rowan Warehouse', 2.61)
# (306, 42386001, 'Quick Seasoned Hamburger ', 65, 'Hamburger', 'Hamburger', 'Meat', 'Food', '14.6', 12, 'Hamburger', 'Quick', 'Rowan Warehouse', 3.64)
# (310, 42390001, 'Life Cereal', 35, 'Cereal', 'Cereal', 'Breakfast Foods', 'Food', '13 oz', 12, 'Cereal', 'Quaker', 'Rowan Warehouse', 2.5)
# (311, 42391001, 'Life Cinnamon Cereal', 35, 'Cereal', 'Cereal', 'Breakfast Foods', 'Food', '13 oz', 12, 'Cereal', 'Quaker', 'Rowan Warehouse', 2.5)
# (312, 42392001, 'Ohs Honey Graham Cereal', 35, 'Cereal', 'Cereal', 'Breakfast Foods', 'Food', '10.5 oz', 12, 'Cereal', 'Quaker', 'Rowan Warehouse', 2.99)
# (359, 42439001, 'Fruity Pebbles Cereal', 35, 'Cereal', 'Cereal', 'Breakfast Foods', 'Food', '15 oz', 12, 'Cereal', 'Post', 'Rowan Warehouse', 3.28)
# (360, 42440001, 'Great Grains Crunchy Pecan Cereal', 35, 'Cereal', 'Cereal', 'Breakfast Foods', 'Food', '16 oz', 12, 'Cereal', 'Post', 'Rowan Warehouse', 4.39)
# (361, 42441001, 'Great Grains Date Pecan Raisin Cereal', 35, 'Cereal', 'Cereal', 'Breakfast Foods', 'Food', '16 oz', 12, 'Cereal', 'Post', 'Rowan Warehouse', 4.39)
# (362, 42442001, 'Honey Bunches Of Oat Honey Roasted Cereal', 35, 'Cereal', 'Cereal', 'Breakfast Foods', 'Food', '18 oz', 12, 'Cereal', 'Post', 'Rowan Warehouse', 2.99)
# (363, 42443001, 'Honey Bunches Of Oats Almond Cereal', 35, 'Cereal', 'Cereal', 'Breakfast Foods', 'Food', '14.5 oz', 12, 'Cereal', 'Post', 'Rowan Warehouse', 4.39)
# (364, 42444001, 'Honey Bunches Of Oats Greek Honey Crunch Cereal', 35, 'Cereal', 'Cereal', 'Breakfast Foods', 'Food', '12.5 oz', 12, 'Cereal', 'Post', 'Rowan Warehouse', 4.39)
# (365, 42445001, 'Honey Bunches Of Oats Honet Roasted Cereal', 35, 'Cereal', 'Cereal', 'Breakfast Foods', 'Food', '14.5 oz', 12, 'Cereal', 'Post', 'Rowan Warehouse', 4.39)
# (366, 42446001, 'Honey Bunches Of Oats Honey Roasted Cereal', 35, 'Cereal', 'Cereal', 'Breakfast Foods', 'Food', '48 oz', 12, 'Cereal', 'Post', 'Rowan Warehouse', 8.79)
# (367, 42447001, 'Honey Bunches Of Oats Morning Energy Chocolate Almond Crunch Cereal', 35, 'Cereal', 'Cereal', 'Breakfast Foods', 'Food', '12.5 oz', 12, 'Cereal', 'Post', 'Rowan Warehouse', 4.39)
# (368, 42448001, 'Honey Bunches Of Oats Morning Energy Cinnamon Crunch Cereal', 35, 'Cereal', 'Cereal', 'Breakfast Foods', 'Food', '12.5 oz', 12, 'Cereal', 'Post', 'Rowan Warehouse', 4.39)
# (369, 42449001, 'Honey Bunches Of Oats Strawberry Cereal', 35, 'Cereal', 'Cereal', 'Breakfast Foods', 'Food', '13 oz', 12, 'Cereal', 'Post', 'Rowan Warehouse', 4.39)
# (370, 42450001, 'Honey Bunches Of Oats With Almonds Cereal', 35, 'Cereal', 'Cereal', 'Breakfast Foods', 'Food', '18 oz', 12, 'Cereal', 'Post', 'Rowan Warehouse', 2.99)
# (371, 42451001, 'Pleasant Beef Soup ', 58, 'Soup', 'Soup', 'Canned Foods', 'Food', '14.8', 12, 'Soup', 'Pleasant', 'Rowan Warehouse', 1.43)
# (372, 42452001, 'Pleasant Canned Beets ', 62, 'Canned Vegetables', 'Canned Vegetables', 'Canned Foods', 'Food', '7.71', 12, 'Canned Vegetables', 'Pleasant', 'Rowan Warehouse', 0.72)
# (373, 42453001, 'Pleasant Canned Peas ', 62, 'Canned Vegetables', 'Canned Vegetables', 'Canned Foods', 'Food', '17.8', 12, 'Canned Vegetables', 'Pleasant', 'Rowan Warehouse', 2.54)
# (374, 42454001, 'Pleasant Canned String Beans ', 62, 'Canned Vegetables', 'Canned Vegetables', 'Canned Foods', 'Food', '6.5', 12, 'Canned Vegetables', 'Pleasant', 'Rowan Warehouse', 1.6)
# (375, 42455001, 'Pleasant Canned Tomatos ', 62, 'Canned Vegetables', 'Canned Vegetables', 'Canned Foods', 'Food', '3.11', 12, 'Canned Vegetables', 'Pleasant', 'Rowan Warehouse', 3.5)
# (376, 42456001, 'Pleasant Canned Tuna in Oil ', 93, 'Tuna', 'Tuna', 'Canned Foods', 'Food', '5.9', 12, 'Tuna', 'Pleasant', 'Rowan Warehouse', 1.37)
# (377, 42457001, 'Pleasant Canned Tuna in Water ', 93, 'Tuna', 'Tuna', 'Canned Foods', 'Food', '3.4', 12, 'Tuna', 'Pleasant', 'Rowan Warehouse', 2.96)
# (378, 42458001, 'Pleasant Canned Yams ', 62, 'Canned Vegetables', 'Canned Vegetables', 'Canned Foods', 'Food', '8.5', 12, 'Canned Vegetables', 'Pleasant', 'Rowan Warehouse', 3.97)
# (379, 42459001, 'Pleasant Chicken Noodle Soup ', 58, 'Soup', 'Soup', 'Canned Foods', 'Food', '19.2', 12, 'Soup', 'Pleasant', 'Rowan Warehouse', 1.31)
# (380, 42460001, 'Pleasant Chicken Ramen Soup ', 58, 'Soup', 'Soup', 'Canned Foods', 'Food', '19.2', 12, 'Soup', 'Pleasant', 'Rowan Warehouse', 2.82)
# (381, 42461001, 'Pleasant Chicken Soup ', 58, 'Soup', 'Soup', 'Canned Foods', 'Food', '18.5', 12, 'Soup', 'Pleasant', 'Rowan Warehouse', 1.3)
# (382, 42462001, 'Pleasant Creamed Corn ', 62, 'Canned Vegetables', 'Canned Vegetables', 'Canned Foods', 'Food', '8', 12, 'Canned Vegetables', 'Pleasant', 'Rowan Warehouse', 1.18)
# (383, 42463001, 'Pleasant Noodle Soup ', 58, 'Soup', 'Soup', 'Canned Foods', 'Food', '16.2', 12, 'Soup', 'Pleasant', 'Rowan Warehouse', 2.48)
# (384, 42464001, 'Pleasant Regular Ramen Soup ', 58, 'Soup', 'Soup', 'Canned Foods', 'Food', '9.5', 12, 'Soup', 'Pleasant', 'Rowan Warehouse', 3.31)
# (385, 42465001, 'Pleasant Rice Soup ', 58, 'Soup', 'Soup', 'Canned Foods', 'Food', '12', 12, 'Soup', 'Pleasant', 'Rowan Warehouse', 0.9)
# (386, 42466001, 'Pleasant Turkey Noodle Soup ', 58, 'Soup', 'Soup', 'Canned Foods', 'Food', '12.5', 12, 'Soup', 'Pleasant', 'Rowan Warehouse', 1.17)
# (387, 42467001, 'Pleasant Vegetable Soup ', 58, 'Soup', 'Soup', 'Canned Foods', 'Food', '18.5', 12, 'Soup', 'Pleasant', 'Rowan Warehouse', 2.69)
# (388, 42468001, 'Plato Brown Sugar ', 50, 'Sugar', 'Sugar', 'Baking Goods', 'Food', '8.19', 12, 'Sugar', 'Plato', 'Rowan Warehouse', 1.24)
# (389, 42469001, 'Plato Canola Oil ', 49, 'Cooking Oil', 'Cooking Oil', 'Baking Goods', 'Food', '6.94', 12, 'Cooking Oil', 'Plato', 'Rowan Warehouse', 1.13)
# (390, 42470001, 'Plato Chunky Peanut Butter ', 53, 'Peanut Butter', 'Peanut Butter', 'Baking Goods', 'Food', '9', 12, 'Peanut Butter', 'Plato', 'Rowan Warehouse', 2.45)
# (391, 42471001, 'Plato Corn Oil ', 49, 'Cooking Oil', 'Cooking Oil', 'Baking Goods', 'Food', '10.3', 12, 'Cooking Oil', 'Plato', 'Rowan Warehouse', 0.77)
# (392, 42472001, 'Plato Creamy Peanut Butter ', 53, 'Peanut Butter', 'Peanut Butter', 'Baking Goods', 'Food', '17.2', 12, 'Peanut Butter', 'Plato', 'Rowan Warehouse', 2.32)
# (393, 42473001, 'Plato Extra Chunky Peanut Butter ', 53, 'Peanut Butter', 'Peanut Butter', 'Baking Goods', 'Food', '16.2', 12, 'Peanut Butter', 'Plato', 'Rowan Warehouse', 1.68)
# (394, 42474001, 'Plato Oregano ', 4, 'Spices', 'Spices', 'Baking Goods', 'Food', '14.6', 12, 'Spices', 'Plato', 'Rowan Warehouse', 2.26)
# (395, 42475001, 'Plato Pepper ', 4, 'Spices', 'Spices', 'Baking Goods', 'Food', '13.5', 12, 'Spices', 'Plato', 'Rowan Warehouse', 3.32)
# (396, 42476001, 'Plato Salt ', 4, 'Spices', 'Spices', 'Baking Goods', 'Food', '13.8', 12, 'Spices', 'Plato', 'Rowan Warehouse', 1.47)
# (397, 42477001, 'Plato Sesame Oil ', 49, 'Cooking Oil', 'Cooking Oil', 'Baking Goods', 'Food', '19.7', 12, 'Cooking Oil', 'Plato', 'Rowan Warehouse', 1.49)
# (398, 42478001, 'Plato Vegetable Oil ', 49, 'Cooking Oil', 'Cooking Oil', 'Baking Goods', 'Food', '12.5', 12, 'Cooking Oil', 'Plato', 'Rowan Warehouse', 1.3)
# (399, 42479001, 'Plato White Sugar ', 50, 'Sugar', 'Sugar', 'Baking Goods', 'Food', '9.39', 12, 'Sugar', 'Plato', 'Rowan Warehouse', 1.72)
# (405, 42485001, 'PigTail Beef TV Dinner ', 10, 'TV Dinner', 'TV Dinner', 'Frozen Foods', 'Food', '13.5', 12, 'TV Dinner', 'PigTail', 'Rowan Warehouse', 2.14)
# (406, 42486001, 'PigTail Chicken TV Dinner ', 10, 'TV Dinner', 'TV Dinner', 'Frozen Foods', 'Food', '16.3', 12, 'TV Dinner', 'PigTail', 'Rowan Warehouse', 1.11)
# (407, 42487001, 'PigTail Fajita French Fries ', 63, 'French Fries', 'French Fries', 'Frozen Foods', 'Food', '4.88', 12, 'French Fries', 'PigTail', 'Rowan Warehouse', 2.31)
# (408, 42488001, 'PigTail Frozen Broccoli ', 60, 'Frozen Vegetables', 'Frozen Vegetables', 'Frozen Foods', 'Food', '8.19', 12, 'Frozen Vegetables', 'PigTail', 'Rowan Warehouse', 1.27)
# (409, 42489001, 'PigTail Frozen Carrots ', 60, 'Frozen Vegetables', 'Frozen Vegetables', 'Frozen Foods', 'Food', '4.98', 12, 'Frozen Vegetables', 'PigTail', 'Rowan Warehouse', 1.91)
# (410, 42490001, 'PigTail Frozen Cauliflower ', 60, 'Frozen Vegetables', 'Frozen Vegetables', 'Frozen Foods', 'Food', '5.76', 12, 'Frozen Vegetables', 'PigTail', 'Rowan Warehouse', 1.57)
# (411, 42491001, 'PigTail Frozen Cheese Pizza ', 64, 'Pizza', 'Pizza', 'Frozen Foods', 'Food', '9.6', 12, 'Pizza', 'PigTail', 'Rowan Warehouse', 2.64)
# (412, 42492001, 'PigTail Frozen Chicken Breast ', 100, 'Frozen Chicken', 'Frozen Chicken', 'Frozen Foods', 'Food', '10.5', 12, 'Frozen Chicken', 'PigTail', 'Rowan Warehouse', 1.51)
# (413, 42493001, 'PigTail Frozen Chicken Thighs ', 100, 'Frozen Chicken', 'Frozen Chicken', 'Frozen Foods', 'Food', '17.5', 12, 'Frozen Chicken', 'PigTail', 'Rowan Warehouse', 2.21)
# (414, 42494001, 'PigTail Frozen Chicken Wings ', 100, 'Frozen Chicken', 'Frozen Chicken', 'Frozen Foods', 'Food', '5.35', 12, 'Frozen Chicken', 'PigTail', 'Rowan Warehouse', 3.93)
# (415, 42495001, 'PigTail Frozen Corn ', 60, 'Frozen Vegetables', 'Frozen Vegetables', 'Frozen Foods', 'Food', '11.6', 12, 'Frozen Vegetables', 'PigTail', 'Rowan Warehouse', 3.7)
# (416, 42496001, 'PigTail Frozen Mushroom Pizza ', 64, 'Pizza', 'Pizza', 'Frozen Foods', 'Food', '8.1', 12, 'Pizza', 'PigTail', 'Rowan Warehouse', 1.21)
# (417, 42497001, 'PigTail Frozen Peas ', 60, 'Frozen Vegetables', 'Frozen Vegetables', 'Frozen Foods', 'Food', '7.84', 12, 'Frozen Vegetables', 'PigTail', 'Rowan Warehouse', 1.66)
# (418, 42498001, 'PigTail Frozen Pepperoni Pizza ', 64, 'Pizza', 'Pizza', 'Frozen Foods', 'Food', '3.05', 12, 'Pizza', 'PigTail', 'Rowan Warehouse', 1.68)
# (419, 42499001, 'PigTail Frozen Sausage Pizza ', 64, 'Pizza', 'Pizza', 'Frozen Foods', 'Food', '16.7', 12, 'Pizza', 'PigTail', 'Rowan Warehouse', 1.45)
# (420, 42500001, 'PigTail Grape Popsicles ', 110, 'Popsicles', 'Popsicles', 'Frozen Foods', 'Food', '14.5', 12, 'Popsicles', 'PigTail', 'Rowan Warehouse', 0.74)
# (421, 42501001, 'PigTail Home Style French Fries ', 63, 'French Fries', 'French Fries', 'Frozen Foods', 'Food', '7.93', 12, 'French Fries', 'PigTail', 'Rowan Warehouse', 0.81)
# (422, 42502001, 'PigTail Ice Cream ', 9, 'Ice Cream', 'Ice Cream', 'Frozen Foods', 'Food', '18', 12, 'Ice Cream', 'PigTail', 'Rowan Warehouse', 0.71)
# (423, 42503001, 'PigTail Ice Cream Sandwich ', 9, 'Ice Cream', 'Ice Cream', 'Frozen Foods', 'Food', '14.6', 12, 'Ice Cream', 'PigTail', 'Rowan Warehouse', 1.15)
# (424, 42504001, 'PigTail Lemon Popsicles ', 110, 'Popsicles', 'Popsicles', 'Frozen Foods', 'Food', '13.3', 12, 'Popsicles', 'PigTail', 'Rowan Warehouse', 1.28)
# (425, 42505001, 'PigTail Lime Popsicles ', 110, 'Popsicles', 'Popsicles', 'Frozen Foods', 'Food', '15', 12, 'Popsicles', 'PigTail', 'Rowan Warehouse', 1.32)
# (426, 42506001, 'PigTail Low Fat French Fries ', 63, 'French Fries', 'French Fries', 'Frozen Foods', 'Food', '6.53', 12, 'French Fries', 'PigTail', 'Rowan Warehouse', 3.95)
# (427, 42507001, 'PigTail Orange Popsicles ', 110, 'Popsicles', 'Popsicles', 'Frozen Foods', 'Food', '10.6', 12, 'Popsicles', 'PigTail', 'Rowan Warehouse', 1.22)
# (428, 42508001, 'PigTail Turkey TV Dinner ', 10, 'TV Dinner', 'TV Dinner', 'Frozen Foods', 'Food', '19.8', 12, 'TV Dinner', 'PigTail', 'Rowan Warehouse', 2.91)
# (432, 42512001, 'Diet Soda', 19, 'Soda', 'Soda', 'Beverages', 'Drink', '67.6 oz', 12, 'Soda', 'Pepsi', 'Rowan Warehouse', 1.5)
# (433, 42513001, 'Original Soda', 19, 'Soda', 'Soda', 'Beverages', 'Drink', '67.6 oz', 12, 'Soda', 'Pepsi', 'Rowan Warehouse', 1.5)
# (519, 42599001, 'Baby Dry Size 1', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '44 ct', 12, 'Diapers', 'Pampers', 'Rowan Warehouse', 10.49)
# (520, 42600001, 'Baby Dry Size 2', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '37 ct', 12, 'Diapers', 'Pampers', 'Rowan Warehouse', 10.49)
# (521, 42601001, 'Baby Dry Size 3', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '32 ct', 12, 'Diapers', 'Pampers', 'Rowan Warehouse', 10.49)
# (522, 42602001, 'Baby Dry Size 3', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '56 ct', 12, 'Diapers', 'Pampers', 'Rowan Warehouse', 18.99)
# (523, 42603001, 'Baby Dry Size 3', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '60 ct', 12, 'Diapers', 'Pampers', 'Rowan Warehouse', 18.79)
# (524, 42604001, 'Baby Dry Size 4', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '28 ct', 12, 'Diapers', 'Pampers', 'Rowan Warehouse', 10.49)
# (525, 42605001, 'Baby Dry Size 5', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '24 ct', 12, 'Diapers', 'Pampers', 'Rowan Warehouse', 10.49)
# (526, 42606001, 'Baby Dry Size 5', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '27 ct', 12, 'Diapers', 'Pampers', 'Rowan Warehouse', 10.99)
# (527, 42607001, 'Baby Dry Size 5', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '78 ct', 12, 'Diapers', 'Pampers', 'Rowan Warehouse', 28.49)
# (528, 42608001, 'Baby Dry Size 6', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '21 ct', 12, 'Diapers', 'Pampers', 'Rowan Warehouse', 10.49)
# (529, 42609001, 'Baby Dry Size 6', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '23 ct', 12, 'Diapers', 'Pampers', 'Rowan Warehouse', 10.49)
# (530, 42610001, 'Cruisers Size 3', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '31 ct', 12, 'Diapers', 'Pampers', 'Rowan Warehouse', 10.99)
# (531, 42611001, 'Cruisers Size 4', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '24 ct', 12, 'Diapers', 'Pampers', 'Rowan Warehouse', 10.29)
# (532, 42612001, 'Cruisers Size 4', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '26 ct', 12, 'Diapers', 'Pampers', 'Rowan Warehouse', 10.99)
# (533, 42613001, 'Cruisers Size 5', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '21 ct', 12, 'Diapers', 'Pampers', 'Rowan Warehouse', 9.99)
# (534, 42614001, 'Cruisers Size 5', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '23 ct', 12, 'Diapers', 'Pampers', 'Rowan Warehouse', 10.99)
# (535, 42615001, 'Cruisers Size 5', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '52 ct', 12, 'Diapers', 'Pampers', 'Rowan Warehouse', 26.99)
# (536, 42616001, 'Cruisers Size 5', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '66 ct', 12, 'Diapers', 'Pampers', 'Rowan Warehouse', 26.99)
# (537, 42617001, 'Cruisers Size 5', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '72 ct', 12, 'Diapers', 'Pampers', 'Rowan Warehouse', 29.99)
# (538, 42618001, 'Swaddlers Size 1', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '35 ct', 12, 'Diapers', 'Pampers', 'Rowan Warehouse', 10.49)
# (539, 42619001, 'Swaddlers Size 2', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '32 ct', 12, 'Diapers', 'Pampers', 'Rowan Warehouse', 10.49)
# (540, 42620001, 'Swaddlers Size Newborn', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '32 ct', 12, 'Diapers', 'Pampers', 'Rowan Warehouse', 10.49)
# (541, 42621001, 'Swaddlers Size Newborn', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '36 ct', 12, 'Diapers', 'Pampers', 'Rowan Warehouse', 10.99)
# (571, 42651001, 'Honey Flake & Oat Clusters Cereal', 35, 'Cereal', 'Cereal', 'Breakfast Foods', 'Food', '14 oz', 12, 'Cereal', 'O Organics', 'Rowan Warehouse', 3.29)
# (572, 42652001, 'Honey Nut Os Cereal', 35, 'Cereal', 'Cereal', 'Breakfast Foods', 'Food', '14 oz', 12, 'Cereal', 'O Organics', 'Rowan Warehouse', 3.29)
# (573, 42653001, 'Multi Grain Squares Cereal', 35, 'Cereal', 'Cereal', 'Breakfast Foods', 'Food', '13 oz', 12, 'Cereal', 'O Organics', 'Rowan Warehouse', 3.29)
# (574, 42654001, 'Raisin Bran Cereal', 35, 'Cereal', 'Cereal', 'Breakfast Foods', 'Food', '15 oz', 12, 'Cereal', 'O Organics', 'Rowan Warehouse', 3.29)
# (594, 42674001, 'Nationeel Avocado Dip ', 83, 'Dips', 'Dips', 'Snack Foods', 'Food', '8.19', 12, 'Dips', 'Nationeel', 'Rowan Warehouse', 2.41)
# (595, 42675001, 'Nationeel Buttered Popcorn ', 54, 'Popcorn', 'Popcorn', 'Snack Foods', 'Food', '6.31', 12, 'Popcorn', 'Nationeel', 'Rowan Warehouse', 2.51)
# (596, 42676001, 'Nationeel Cheese Dip ', 83, 'Dips', 'Dips', 'Snack Foods', 'Food', '8.69', 12, 'Dips', 'Nationeel', 'Rowan Warehouse', 2.22)
# (597, 42677001, 'Nationeel Chocolate Chip Cookies ', 45, 'Cookies', 'Cookies', 'Snack Foods', 'Food', '14.1', 12, 'Cookies', 'Nationeel', 'Rowan Warehouse', 3.31)
# (598, 42678001, 'Nationeel Fondue Mix ', 83, 'Dips', 'Dips', 'Snack Foods', 'Food', '5.98', 12, 'Dips', 'Nationeel', 'Rowan Warehouse', 2.22)
# (599, 42679001, 'Nationeel Frosted Cookies ', 45, 'Cookies', 'Cookies', 'Snack Foods', 'Food', '10.5', 12, 'Cookies', 'Nationeel', 'Rowan Warehouse', 1.63)
# (600, 42680001, 'Nationeel Fudge Brownies ', 45, 'Cookies', 'Cookies', 'Snack Foods', 'Food', '13.2', 12, 'Cookies', 'Nationeel', 'Rowan Warehouse', 1.71)
# (601, 42681001, 'Nationeel Fudge Cookies ', 45, 'Cookies', 'Cookies', 'Snack Foods', 'Food', '5.3', 12, 'Cookies', 'Nationeel', 'Rowan Warehouse', 1.42)
# (602, 42682001, 'Nationeel Graham Crackers ', 45, 'Cookies', 'Cookies', 'Snack Foods', 'Food', '6.31', 12, 'Cookies', 'Nationeel', 'Rowan Warehouse', 1.65)
# (603, 42683001, 'Nationeel Lemon Cookies ', 45, 'Cookies', 'Cookies', 'Snack Foods', 'Food', '12.8', 12, 'Cookies', 'Nationeel', 'Rowan Warehouse', 2.26)
# (604, 42684001, 'Nationeel Low Fat Cookies ', 45, 'Cookies', 'Cookies', 'Snack Foods', 'Food', '11.3', 12, 'Cookies', 'Nationeel', 'Rowan Warehouse', 0.66)
# (605, 42685001, 'Nationeel Low Fat Popcorn ', 54, 'Popcorn', 'Popcorn', 'Snack Foods', 'Food', '8.6', 12, 'Popcorn', 'Nationeel', 'Rowan Warehouse', 3.88)
# (606, 42686001, 'Nationeel No Salt Popcorn ', 54, 'Popcorn', 'Popcorn', 'Snack Foods', 'Food', '6.63', 12, 'Popcorn', 'Nationeel', 'Rowan Warehouse', 0.69)
# (607, 42687001, 'Nationeel Salsa Dip ', 83, 'Dips', 'Dips', 'Snack Foods', 'Food', '7.89', 12, 'Dips', 'Nationeel', 'Rowan Warehouse', 1.6)
# (608, 42688001, 'Nationeel Sugar Cookies ', 45, 'Cookies', 'Cookies', 'Snack Foods', 'Food', '6.23', 12, 'Cookies', 'Nationeel', 'Rowan Warehouse', 2.94)
# (639, 42719001, 'Musial Malted Milk Balls ', 36, 'Chocolate Candy', 'Chocolate Candy', 'Snacks', 'Food', '10.8', 12, 'Chocolate Candy', 'Musial', 'Rowan Warehouse', 0.89)
# (640, 42720001, 'Musial Mint Chocolate Bar ', 36, 'Chocolate Candy', 'Chocolate Candy', 'Snacks', 'Food', '12.5', 12, 'Chocolate Candy', 'Musial', 'Rowan Warehouse', 0.98)
# (641, 42721001, 'Musial Mints ', 38, 'Hard Candy', 'Hard Candy', 'Snacks', 'Food', '7.3', 12, 'Hard Candy', 'Musial', 'Rowan Warehouse', 3.14)
# (642, 42722001, 'Musial Semi-Sweet Chocolate Bar ', 36, 'Chocolate Candy', 'Chocolate Candy', 'Snacks', 'Food', '17.6', 12, 'Chocolate Candy', 'Musial', 'Rowan Warehouse', 2.81)
# (643, 42723001, 'Musial Spicy Mints ', 38, 'Hard Candy', 'Hard Candy', 'Snacks', 'Food', '12.6', 12, 'Hard Candy', 'Musial', 'Rowan Warehouse', 2.92)
# (644, 42724001, 'Musial Tasty Candy Bar ', 36, 'Chocolate Candy', 'Chocolate Candy', 'Snacks', 'Food', '16.7', 12, 'Chocolate Candy', 'Musial', 'Rowan Warehouse', 2.1)
# (645, 42725001, 'Musial White Chocolate Bar ', 36, 'Chocolate Candy', 'Chocolate Candy', 'Snacks', 'Food', '14', 12, 'Chocolate Candy', 'Musial', 'Rowan Warehouse', 3.43)
# (646, 42726001, 'Diaper Bag Dispenser', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '1 pkg', 12, 'Diapers', 'Munchkin', 'Rowan Warehouse', 4.29)
# (647, 42727001, 'Diaper Bag Refills', 213, 'Diapers', 'Diapers', 'Household', 'Non-Consumable', '36 ct', 12, 'Diapers', 'Munchkin', 'Rowan Warehouse', 4.39)
# (655, 42735001, 'Monarch Rice Medly ', 57, 'Rice', 'Rice', 'Starchy Foods', 'Food', '11.1', 12, 'Rice', 'Monarch', 'Rowan Warehouse', 1.8)
# (656, 42736001, 'Monarch Thai Rice ', 57, 'Rice', 'Rice', 'Starchy Foods', 'Food', '6.43', 12, 'Rice', 'Monarch', 'Rowan Warehouse', 3.11)
# (657, 42737001, 'Moms Beef Bologna ', 91, 'Bologna', 'Bologna', 'Deli', 'Food', '11.3', 12, 'Bologna', 'Moms', 'Rowan Warehouse', 2.27)
# (658, 42738001, 'Moms Chicken Hot Dogs ', 81, 'Hot Dogs', 'Hot Dogs', 'Deli', 'Food', '10.3', 12, 'Hot Dogs', 'Moms', 'Rowan Warehouse', 1.49)
# (659, 42739001, 'Moms Cole Slaw ', 16, 'Deli Salads', 'Deli Salads', 'Deli', 'Food', '8.3', 12, 'Deli Salads', 'Moms', 'Rowan Warehouse', 2.33)
# (660, 42740001, 'Moms Corned Beef ', 8, 'Deli Meats', 'Deli Meats', 'Deli', 'Food', '11.1', 12, 'Deli Meats', 'Moms', 'Rowan Warehouse', 2.75)
# (661, 42741001, 'Moms Foot-Long Hot Dogs ', 81, 'Hot Dogs', 'Hot Dogs', 'Deli', 'Food', '14.2', 12, 'Hot Dogs', 'Moms', 'Rowan Warehouse', 3.85)
# (662, 42742001, 'Moms Low Fat Bologna ', 91, 'Bologna', 'Bologna', 'Deli', 'Food', '17', 12, 'Bologna', 'Moms', 'Rowan Warehouse', 2.1)
# (663, 42743001, 'Moms Low Fat Cole Slaw ', 16, 'Deli Salads', 'Deli Salads', 'Deli', 'Food', '19.3', 12, 'Deli Salads', 'Moms', 'Rowan Warehouse', 1.22)
# (664, 42744001, 'Moms Pimento Loaf ', 91, 'Bologna', 'Bologna', 'Deli', 'Food', '17.3', 12, 'Bologna', 'Moms', 'Rowan Warehouse', 2.29)
# (665, 42745001, 'Moms Potato Salad ', 16, 'Deli Salads', 'Deli Salads', 'Deli', 'Food', '13.8', 12, 'Deli Salads', 'Moms', 'Rowan Warehouse', 2.23)
# ...
# (198, 42278001, 'Chunk Light Tuna Water (pouch)', 93, 'Tuna', 'Tuna', 'Canned Foods', 'Food', '7.06 oz', 12, 'Tuna', 'Starkist', 'Rowan Warehouse', 2.29)
# (222, 42302001, 'Vinegar Balsamic', 48, 'Sauces', 'Sauces', 'Baking Goods', 'Food', '8.5 oz', 12, 'Sauces', 'Star', 'Rowan Warehouse', 2.99)
# (225, 42305001, 'Baby Lotion Original', 79, 'Shampoo', 'Shampoo', 'Health and Hygiene', 'Non-Consumable', '1 ct', 12, 'Shampoo', 'Soft & Precious', 'Rowan Warehouse', 2.99)
# (226, 42306001, 'Hair Moist Creme', 79, 'Shampoo', 'Shampoo', 'Health and Hygiene', 'Non-Consumable', '4 oz', 12, 'Shampoo', 'Soft & Precious', 'Rowan Warehouse', 3.99)
# (227, 42307001, 'Hair Moisturizer Detangling', 79, 'Shampoo', 'Shampoo', 'Health and Hygiene', 'Non-Consumable', '12 oz', 12, 'Shampoo', 'Soft & Precious', 'Rowan Warehouse', 3.99)
# (228, 42308001, 'Tortilla Chips Original', 12, 'Chips', 'Chips', 'Snack Foods', 'Food', '16 oz', 12, 'Chips', 'Snyders Of Hanover', 'Rowan Warehouse', 2.99)
# (249, 42329001, 'Sponges Blue', 42, 'Sponges', 'Sponges', 'Household', 'Non-Consumable', '3 pkg', 12, 'Sponges', 'Scotch-Brite', 'Rowan Warehouse', 2.49)
# (250, 42330001, 'English Muffins Original', 25, 'Bagels', 'Bagels', 'Baked Goods', 'Food', '12 oz', 12, 'Bagels', 'Schmidt Old Tyme', 'Rowan Warehouse', 1.49)
# (252, 42332001, 'Tastings Medium Asiago', 11, 'Cheese', 'Cheese', 'Dairy', 'Food', '3.25 oz', 12, 'Cheese', 'Sargento', 'Rowan Warehouse', 2.79)
# (253, 42333001, 'Tastings Parmentino', 11, 'Cheese', 'Cheese', 'Dairy', 'Food', '3.75 oz', 12, 'Cheese', 'Sargento', 'Rowan Warehouse', 2.99)
# (282, 42362001, 'Sugar White', 50, 'Sugar', 'Sugar', 'Baking Goods', 'Food', '4 lbs', 12, 'Sugar', 'Rowan', 'Rowan Warehouse', 1.69)
# (283, 42363001, 'Honey Wheat Rods Pretzels', 82, 'Crackers', 'Crackers', 'Snack Foods', 'Food', '10 oz', 12, 'Crackers', 'Rolled Gold', 'Rowan Warehouse', 3.29)
# (284, 42364001, 'Peanut Butter Cups King Size', 36, 'Chocolate Candy', 'Chocolate Candy', 'Snacks', 'Food', '2.8 oz', 12, 'Chocolate Candy', 'Reeses', 'Rowan Warehouse', 1.69)
# (303, 42383001, 'Stone Wheat Thins Original', 82, 'Crackers', 'Crackers', 'Snack Foods', 'Food', '10.6 oz', 12, 'Crackers', 'Red Oval Farms', 'Rowan Warehouse', 4.19)
# (315, 42395001, 'Sausage Pork', 81, 'Hot Dogs', 'Hot Dogs', 'Deli', 'Food', '1 lbs', 12, 'Hot Dogs', 'Purnell', 'Rowan Warehouse', 3.29)
# (316, 42396001, 'Lettuce Head', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '1 ct', 12, 'Fresh Vegetables', 'Produce', 'Rowan Warehouse', 1.09)
# (317, 42397001, 'Turnip Greens Vegetables', 13, 'Fresh Vegetables', 'Fresh Vegetables', 'Produce', 'Food', '1 lbs', 12, 'Fresh Vegetables', 'Produce', 'Rowan Warehouse', 1.29)
# (400, 42480001, 'Grands Biscuits Buttermilk', 28, 'Pancake Mix', 'Pancake Mix', 'Frozen Foods', 'Food', '20 ct', 12, 'Pancake Mix', 'Pillsbury', 'Rowan Warehouse', 3.99)
# (401, 42481001, 'Grands Biscuits Flaky Layers Buttermilk', 28, 'Pancake Mix', 'Pancake Mix', 'Frozen Foods', 'Food', '16.3 oz', 12, 'Pancake Mix', 'Pillsbury', 'Rowan Warehouse', 1.99)
# (402, 42482001, 'Grands Biscuits Southern Homestyle Buttermilk', 28, 'Pancake Mix', 'Pancake Mix', 'Frozen Foods', 'Food', '10.2 oz', 12, 'Pancake Mix', 'Pillsbury', 'Rowan Warehouse', 1.59)
# (403, 42483001, 'Grands Biscuits Southern Homestyle Buttermilk', 28, 'Pancake Mix', 'Pancake Mix', 'Frozen Foods', 'Food', '16.3 oz', 12, 'Pancake Mix', 'Pillsbury', 'Rowan Warehouse', 1.99)
# (404, 42484001, 'Grands Junior Biscuits Flaky Layers Buttermilk', 28, 'Pancake Mix', 'Pancake Mix', 'Frozen Foods', 'Food', '6 oz', 12, 'Pancake Mix', 'Pillsbury', 'Rowan Warehouse', 1.29)
# (431, 42511001, 'Evaporated Milk Original', 50, 'Sugar', 'Sugar', 'Baking Goods', 'Food', '12 oz', 12, 'Sugar', 'Pet', 'Rowan Warehouse', 1.79)
# (515, 42595001, 'Chopped Beef Dog Food', 214, 'Pet Food', 'Pet Food', 'Household', 'Non-Consumable', '22 oz', 12, 'Pet Food', 'Pedigree', 'Rowan Warehouse', 1.28)
# (516, 42596001, 'Cough & Congestion Cherry', 70, 'Aspirin', 'Aspirin', 'Health and Hygiene', 'Non-Consumable', '4 oz', 12, 'Aspirin', 'Pediacare', 'Rowan Warehouse', 6.79)
# (517, 42597001, 'Pasta Butter And Garlic', 5, 'Pasta', 'Pasta', 'Starchy Foods', 'Food', '4.7 oz', 12, 'Pasta', 'Pasta Roni', 'Rowan Warehouse', 1.0)
# (542, 42622001, 'Oxy Blue', 21, 'Cleaners', 'Cleaners', 'Household', 'Non-Consumable', '25 oz', 12, 'Cleaners', 'Palmolive', 'Rowan Warehouse', 2.79)
# (543, 42623001, 'Oxi Clean Laundry Detergent', 21, 'Cleaners', 'Cleaners', 'Household', 'Non-Consumable', '47 oz', 12, 'Cleaners', 'Oxi Clean', 'Rowan Warehouse', 2.99)
# (547, 42627001, 'Hot Dogs Regular', 81, 'Hot Dogs', 'Hot Dogs', 'Deli', 'Food', '16 oz', 12, 'Hot Dogs', 'Oscar Mayer', 'Rowan Warehouse', 2.49)
# (548, 42628001, 'Hot Dogs Turkey Smoked', 81, 'Hot Dogs', 'Hot Dogs', 'Deli', 'Food', '16 oz', 12, 'Hot Dogs', 'Oscar Mayer', 'Rowan Warehouse', 2.49)
# (549, 42629001, 'Microwave Popcorn Butter', 54, 'Popcorn', 'Popcorn', 'Snack Foods', 'Food', '6 pkg', 12, 'Popcorn', 'Orville Redenbachers', 'Rowan Warehouse', 3.49)
# (550, 42630001, 'Popcorn Garlic Butter & Sea Salt', 54, 'Popcorn', 'Popcorn', 'Snack Foods', 'Food', '8.07 oz', 12, 'Popcorn', 'Orville Redenbachers', 'Rowan Warehouse', 3.19)
# (552, 42632001, 'French Fries Shoestring', 63, 'French Fries', 'French Fries', 'Frozen Foods', 'Food', '32 oz', 12, 'French Fries', 'Ore Ida', 'Rowan Warehouse', 2.0)
# (557, 42637001, 'Taco Seasoning Original', 4, 'Spices', 'Spices', 'Baking Goods', 'Food', '1 oz', 12, 'Spices', 'Old El Paso', 'Rowan Warehouse', 0.83)
# (558, 42638001, 'Craisins Original', 109, 'Dried Fruit', 'Dried Fruit', 'Snack Foods', 'Food', '5 oz', 12, 'Dried Fruit', 'Ocean Spray', 'Rowan Warehouse', 2.49)
# (575, 42655001, 'Spread Hazelnut', 48, 'Sauces', 'Sauces', 'Baking Goods', 'Food', '26.5 oz', 12, 'Sauces', 'Nutella', 'Rowan Warehouse', 6.99)
# (578, 42658001, 'Carnation Reduced Fat', 50, 'Sugar', 'Sugar', 'Baking Goods', 'Food', '12 oz', 12, 'Sugar', 'Nestle', 'Rowan Warehouse', 1.79)
# (582, 42662001, 'Milk Banana Strawberry', 52, 'Flavored Drinks', 'Flavored Drinks', 'Beverages', 'Drink', '14 oz', 12, 'Flavored Drinks', 'Nestle', 'Rowan Warehouse', 1.69)
# (650, 42730001, 'Applesauce Cinnamon', 3, 'Canned Fruit', 'Canned Fruit', 'Canned Products', 'Food', '24 oz', 12, 'Canned Fruit', 'Motts', 'Rowan Warehouse', 3.39)
# (679, 42760001, 'Vanilla, Butter & Nut Exctract', 4, 'Spices', 'Spices', 'Baking Goods', 'Food', '2 oz', 12, 'Spices', 'Mccormick', 'Rowan Warehouse', 6.0)
# (700, 42782001, 'Rice Brown', 57, 'Rice', 'Rice', 'Starchy Foods', 'Food', '2 lbs', 12, 'Rice', 'Mahatma', 'Rowan Warehouse', 2.19)
# (701, 42783001, 'Rice Jasmine', 57, 'Rice', 'Rice', 'Starchy Foods', 'Food', '2 lbs', 12, 'Rice', 'Mahatma', 'Rowan Warehouse', 2.89)
# (702, 42784001, 'Rice White', 57, 'Rice', 'Rice', 'Starchy Foods', 'Food', '2 lbs', 12, 'Rice', 'Mahatma', 'Rowan Warehouse', 2.19)
# (709, 42791001, 'Gas Relief Drops Natural Berry', 70, 'Aspirin', 'Aspirin', 'Health and Hygiene', 'Non-Consumable', '1 oz', 12, 'Aspirin', 'Little Tummys', 'Rowan Warehouse', 7.49)
# (710, 42792001, 'Spray & Drops Saline', 70, 'Aspirin', 'Aspirin', 'Health and Hygiene', 'Non-Consumable', '1 oz', 12, 'Aspirin', 'Little Noses', 'Rowan Warehouse', 4.19)
# (727, 42809001, 'Mint Shield Mouthwash', 74, 'Mouthwash', 'Mouthwash', 'Health and Hygiene', 'Non-Consumable', '16.9 oz', 12, 'Mouthwash', 'Listerine', 'Rowan Warehouse', 4.49)
# (736, 42818001, 'Ham & Cheese Whole Grain Crust', 10, 'TV Dinner', 'TV Dinner', 'Frozen Foods', 'Food', '9 oz', 12, 'TV Dinner', 'Lean Pockets', 'Rowan Warehouse', 2.29)
# (766, 42848001, 'Eggs Large', 66, 'Eggs', 'Eggs', 'Eggs', 'Food', '12 ct', 12, 'Eggs', 'Kroger', 'Rowan Warehouse', 1.99)
# (767, 42849001, 'Eggs Large', 66, 'Eggs', 'Eggs', 'Eggs', 'Food', '18 ct', 12, 'Eggs', 'Kroger', 'Rowan Warehouse', 2.99)
# (772, 42854001, 'American Singles 2% Milk', 11, 'Cheese', 'Cheese', 'Dairy', 'Food', '22 pkg', 12, 'Cheese', 'Kraft', 'Rowan Warehouse', 3.49)
# (773, 42855001, 'Cool Whip Regular', 11, 'Cheese', 'Cheese', 'Dairy', 'Food', '8 oz', 12, 'Cheese', 'Kraft', 'Rowan Warehouse', 1.99)
# (784, 42867001, 'Cooking Stock Chicken', 58, 'Soup', 'Soup', 'Canned Foods', 'Food', '32 oz', 12, 'Soup', 'Kitchen Basics', 'Rowan Warehouse', 2.99)
# (785, 42868001, 'Flour All Purpose', 48, 'Sauces', 'Sauces', 'Baking Goods', 'Food', '5 lbs', 12, 'Sauces', 'King Arthur', 'Rowan Warehouse', 3.99)
# (881, 42964001, 'Baby Oil Original', 79, 'Shampoo', 'Shampoo', 'Health and Hygiene', 'Non-Consumable', '3 oz', 12, 'Shampoo', 'Johnsons', 'Rowan Warehouse', 2.29)
# (882, 42965001, 'Baby Powder Original', 79, 'Shampoo', 'Shampoo', 'Health and Hygiene', 'Non-Consumable', '9 oz', 12, 'Shampoo', 'Johnsons', 'Rowan Warehouse', 2.99)
# (883, 42966001, 'Baby Shampoo Original', 79, 'Shampoo', 'Shampoo', 'Health and Hygiene', 'Non-Consumable', '15 oz', 12, 'Shampoo', 'Johnsons', 'Rowan Warehouse', 4.49)
# (923, 43006001, 'Mashed Potatoes Four Cheese', 57, 'Rice', 'Rice', 'Starchy Foods', 'Food', '4 oz', 12, 'Rice', 'Idahoan', 'Rowan Warehouse', 1.29)
# (965, 43048001, 'Cupcakes Chocolate', 26, 'Muffins', 'Muffins', 'Baked Goods', 'Food', '12.7 oz', 12, 'Muffins', 'Hostess', 'Rowan Warehouse', 3.29)
# (966, 43049001, 'Pie Apple', 45, 'Cookies', 'Cookies', 'Snack Foods', 'Food', '4.5 oz', 12, 'Cookies', 'Hostess', 'Rowan Warehouse', 1.0)
# (1091, 43176001, 'Salsa Mild', 83, 'Dips', 'Dips', 'Snack Foods', 'Food', '24 oz', 12, 'Dips', 'Herdez', 'Rowan Warehouse', 2.99)
# (1093, 43178001, 'Ketchup Original', 48, 'Sauces', 'Sauces', 'Baking Goods', 'Food', '38 oz', 12, 'Sauces', 'Heinz', 'Rowan Warehouse', 2.49)
# (1320, 43405001, 'PopCorners Sea Salt', 12, 'Chips', 'Chips', 'Snack Foods', 'Food', '5 oz', 12, 'Chips', 'Gefen', 'Rowan Warehouse', 2.99)
# (1470, 43555001, 'Air Effects With Gain', 20, 'Deodorizers', 'Deodorizers', 'Household', 'Non-Consumable', '9.7 oz', 12, 'Deodorizers', 'Febreze', 'Rowan Warehouse', 4.29)
# (1555, 43640001, 'Pie Key Lime', 9, 'Ice Cream', 'Ice Cream', 'Frozen Foods', 'Food', '36 oz', 12, 'Ice Cream', 'Edwards', 'Rowan Warehouse', 7.99)
# (1606, 43691001, 'Shortbread Cookies', 45, 'Cookies', 'Cookies', 'Snack Foods', 'Food', '4.4 oz', 12, 'Cookies', 'Eating Right', 'Rowan Warehouse', 3.69)
# (1623, 43708001, 'Bananas Bunch', 99, 'Fresh Fruit', 'Fresh Fruit', 'Produce', 'Food', '1 lbs', 12, 'Fresh Fruit', 'Dole', 'Rowan Warehouse', 0.55)
# (1632, 43717001, 'Baby Shampoo Original', 79, 'Shampoo', 'Shampoo', 'Health and Hygiene', 'Non-Consumable', '12 oz', 12, 'Shampoo', 'Delta', 'Rowan Warehouse', 1.0)
# (1633, 43718001, 'Diced Mango Fruit Cup', 3, 'Canned Fruit', 'Canned Fruit', 'Canned Products', 'Food', '16 oz', 12, 'Canned Fruit', 'Del Monte', 'Rowan Warehouse', 2.5)
# (1634, 43719001, 'Fruit Burst Squeezers Mixed Berry', 3, 'Canned Fruit', 'Canned Fruit', 'Canned Products', 'Food', '12.8 oz', 12, 'Canned Fruit', 'Del Monte', 'Rowan Warehouse', 2.5)
# (1651, 43736001, '3D White Arctic Fresh', 88, 'Toothbrushes', 'Toothbrushes', 'Health and Hygiene', 'Non-Consumable', '7 oz', 12, 'Toothbrushes', 'Crest', 'Rowan Warehouse', 4.37)
# (1654, 43739001, 'Spread Original', 11, 'Cheese', 'Cheese', 'Dairy', 'Food', '45 oz', 12, 'Cheese', 'Country Crock', 'Rowan Warehouse', 3.49)
# (1664, 43749001, 'Rotel Diced Tomatoes& Green Chilies', 62, 'Canned Vegetables', 'Canned Vegetables', 'Canned Foods', 'Food', '10 oz', 12, 'Canned Vegetables', 'Con Agar Foods', 'Rowan Warehouse', 2.99)
# (1688, 43773001, 'Disinfecting Wipes Lemon Fresh', 21, 'Cleaners', 'Cleaners', 'Household', 'Non-Consumable', '35 pkg', 12, 'Cleaners', 'Clorox', 'Rowan Warehouse', 3.39)
# (1689, 43774001, 'Ultra Liquid Bleach Mountain Fresh', 21, 'Cleaners', 'Cleaners', 'Household', 'Non-Consumable', '96 oz', 12, 'Cleaners', 'Clorox', 'Rowan Warehouse', 2.39)
# (1764, 43849001, 'Potato Chips Snacks', 12, 'Chips', 'Chips', 'Snack Foods', 'Food', '8 oz', 12, 'Chips', 'Cape Cod', 'Rowan Warehouse', 2.99)
# (1809, 43894001, 'Condensed Milk Sweetened', 76, 'Milk', 'Milk', 'Dairy', 'Drink', '14 oz', 12, 'Milk', 'Borden', 'Rowan Warehouse', 2.99)
# (1876, 43961001, 'Fruit Snacks SpongeBob', 109, 'Dried Fruit', 'Dried Fruit', 'Snack Foods', 'Food', '10 ct', 12, 'Dried Fruit', 'Betty Crocker', 'Rowan Warehouse', 3.29)
# (2020, 44105001, 'Chicken Breast Stuffed Broccoli & Cheese', 10, 'TV Dinner', 'TV Dinner', 'Frozen Foods', 'Food', '2.5 oz', 12, 'TV Dinner', 'Barber', 'Rowan Warehouse', 5.49)
# (2037, 44122001, 'Sandwich Thins Honey Wheat', 27, 'Sliced Bread', 'Sliced Bread', 'Baked Goods', 'Food', '12 oz', 12, 'Sliced Bread', 'Arnold', 'Rowan Warehouse', 3.49)
# (2038, 44123001, 'Sandwich Thins Multigrain', 27, 'Sliced Bread', 'Sliced Bread', 'Baked Goods', 'Food', '12 oz', 12, 'Sliced Bread', 'Arnold', 'Rowan Warehouse', 3.49)
# (2039, 44124001, 'Sandwich Thins Potato Rolls', 27, 'Sliced Bread', 'Sliced Bread', 'Baked Goods', 'Food', '12 oz', 12, 'Sliced Bread', 'Arnold', 'Rowan Warehouse', 3.49)
# (2040, 44125001, 'Sandwich Thins Whole Wheat', 27, 'Sliced Bread', 'Sliced Bread', 'Baked Goods', 'Food', '12 oz', 12, 'Sliced Bread', 'Arnold', 'Rowan Warehouse', 3.49)
# (2067, 44152001, 'Laundry Detergent 2X Ultra Free Clear', 21, 'Cleaners', 'Cleaners', 'Household', 'Non-Consumable', '50 oz', 12, 'Cleaners', 'All', 'Rowan Warehouse', 11.99)
# (2073, 44158001, 'Popcorn Butter', 54, 'Popcorn', 'Popcorn', 'Snack Foods', 'Food', '6 pkg', 12, 'Popcorn', 'Act II', 'Rowan Warehouse', 3.99)
# (483, 42563001, 'Jewish Pumpernickel Dark Pump', 27, 'Sliced Bread', 'Sliced Bread', 'Baked Goods', 'Food', '16 oz', 12, 'Sliced Bread', 'Pepperidge Farm', 'Rowan Warehouse', 3.79)
# (498, 42578001, 'Texas Toast 5 Cheese', 27, 'Sliced Bread', 'Sliced Bread', 'Baked Goods', 'Food', '9.5 oz', 12, 'Sliced Bread', 'Pepperidge Farm', 'Rowan Warehouse', 2.59)
# (499, 42579001, 'Texas Toast Garlic', 27, 'Sliced Bread', 'Sliced Bread', 'Baked Goods', 'Food', '11 oz', 12, 'Sliced Bread', 'Pepperidge Farm', 'Rowan Warehouse', 3.39)
# (721, 42803001, 'Cupcakes Chocolate', 26, 'Muffins', 'Muffins', 'Baked Goods', 'Food', '14.38 oz', 12, 'Muffins', 'Little Debbie', 'Rowan Warehouse', 3.0)
# (725, 42807001, 'Pie Marshmallow Chocolate', 45, 'Cookies', 'Cookies', 'Snack Foods', 'Food', '12.1 oz', 12, 'Cookies', 'Little Debbie', 'Rowan Warehouse', 2.19)
# (726, 42808001, 'Spin Wheels Pecan', 45, 'Cookies', 'Cookies', 'Snack Foods', 'Food', '8 oz', 12, 'Cookies', 'Little Debbie', 'Rowan Warehouse', 1.99)
# (1549, 43634001, 'Pie Apple', 45, 'Cookies', 'Cookies', 'Snack Foods', 'Food', '26 oz', 12, 'Cookies', 'Entenmanns', 'Rowan Warehouse', 7.49)
# (1550, 43635001, 'Puffs Apple', 45, 'Cookies', 'Cookies', 'Snack Foods', 'Food', '18 oz', 12, 'Cookies', 'Entenmanns', 'Rowan Warehouse', 7.59)
# (792, 42875001, 'Eggo Breakfast Sandwiches Bacon Egg & Cheese', 29, 'Pancakes', 'Pancakes', 'Frozen Foods', 'Food', '4 ct', 12, 'Pancakes', 'Kelloggs', 'Rowan Warehouse', 5.99)
# (793, 42876001, 'Eggo French Toaster Sticks Cinnamon', 29, 'Pancakes', 'Pancakes', 'Frozen Foods', 'Food', '8 ct', 12, 'Pancakes', 'Kelloggs', 'Rowan Warehouse', 3.19)
# (842, 42925001, 'Rice Krispies Treats Marshmallows Squares', 45, 'Cookies', 'Cookies', 'Snack Foods', 'Food', '6.2 oz', 12, 'Cookies', 'Kelloggs', 'Rowan Warehouse', 3.69)
# (853, 42936001, 'Special K Indulgent Moments Dreamy Coconut Snack Bites', 45, 'Cookies', 'Cookies', 'Snack Foods', 'Food', '4.5 oz', 12, 'Cookies', 'Kelloggs', 'Rowan Warehouse', 3.59)
# (854, 42937001, 'Special K Moments Caramel Pretzel Bliss Snack Bites', 45, 'Cookies', 'Cookies', 'Snack Foods', 'Food', '4.5 oz', 12, 'Cookies', 'Kelloggs', 'Rowan Warehouse', 3.59)
# (489, 42569001, 'Stuffing Corn Bread', 4, 'Spices', 'Spices', 'Baking Goods', 'Food', '14 oz', 12, 'Spices', 'Pepperidge Farm', 'Rowan Warehouse', 2.99)
# (190, 42270001, 'Stuffing Mix Pork', 4, 'Spices', 'Spices', 'Baking Goods', 'Food', '6 oz', 12, 'Spices', 'Stove Top', 'Rowan Warehouse', 2.09)
# (1703, 43788001, 'Snack Mix Chocolate Peanut', 12, 'Chips', 'Chips', 'Snack Foods', 'Food', '8 oz', 12, 'Chips', 'Chex Mix', 'Rowan Warehouse', 2.69)
