# %% [markdown]
# ## Product Mapping
# ### Anthony Ung

# %%
import csv
import re

products_old = []
products_mapped = []
new_product_classes = []

# Read the product and product classes files.
with open('Products1.txt', 'r') as csvfile:

    csv.register_dialect('piper', delimiter='|', quoting=csv.QUOTE_NONE)
    for row in csv.DictReader(csvfile, dialect='piper'):
        products_old.append(row)

    with open('product_class.txt', 'r') as csvfile:
        csv.register_dialect('tab', delimiter='\t', quoting=csv.QUOTE_NONE)
        
        for row in csv.DictReader(csvfile, dialect='tab'):
            new_product_classes.append(row)

def pipeline(src, dst1, dst2, func):
    func(src, dst1, dst2)

# ETL 1: Change all the manufacturers to either 'Rowan Warehouse' or 'Rowan Dairy'
def etl_1(src, dst1, dst2=None):
    for product in src:
        if product['itemType'] == 'Milk':
            product['Manufacturer'] = 'Rowan Dairy'
        else:
            product['Manufacturer'] = 'Rowan Warehouse'
    
        dst1.append(product)


# ETL 2: Handle the 1319 products that can directly be mapped to one of the subcategories
def etl_2(src, dst1, dst2):
    product_classes = []
    
    for p_entry in new_product_classes:
        product_classes.append(p_entry['product_subcategory'])
    
    for product in src:
        if product['itemType'] in product_classes:
            product['meta_code'] = 1
            product['meta_entry'] = 'Mapped by AU from old Item type into new subcategory'
            dst1.append(product)
        else:
            product['meta_code'] = -1
            product['meta_entry'] = ''
            dst2.append(product)


# ETL 3 - Bagel
def etl_3(src, dst1, dst2):
    product_classes = []
    
    for p_entry in new_product_classes:
        product_classes.append(p_entry['product_subcategory'])

    pattern = 'Bagel'
    
    for product in src:
        if re.search(pattern, product['Product Name']):
            product['meta_code'] = 2
            product['meta_entry'] = 'Mapped by AU from character match with Bagel'
            dst1.append(product)
        else:
            dst2.append(product)


# ETL 4 - Bread
def etl_4(src, dst1, dst2):
    for product in src:
        if product['itemType'] != 'Bread':
            dst2.append(product)
        else:
            pattern_1 = 'Cheeseburger'
            pattern_2 = 'Chicken'
            pattern_3 = 'Texas Toast'
            
            if re.search(pattern_1, product['Product Name']) \
                or re.search(pattern_2, product['Product Name']) \
                or re.search(pattern_3, product['Product Name']):
            
                dst2.append(product)

            else:
                product['meta_code'] = 3
                product['meta_entry'] = 'Mapped by AU with a character match for Bread ' \
                                            'and assuming all these matches are sliced'
                dst1.append(product)

    
# ETL 1: Change all the manufacturers to either 'Rowan Warehouse' or 'Rowan Dairy'
products_etl_1 = []
pipeline(products_old, products_etl_1, None, etl_1)


# ETL 2: Handle the 1319 products that can directly be mapped to one of the subcategories
products_etl_to_be_mapped_v1 = []
pipeline(products_etl_1, products_mapped, products_etl_to_be_mapped_v1, etl_2)


# ETL 3: Bagels
products_etl_to_be_mapped_v2 = []
pipeline(products_etl_to_be_mapped_v1, products_mapped, products_etl_to_be_mapped_v2, etl_3)


# ETL 4: Bread
products_etl_to_be_mapped_v3 = []
pipeline(products_etl_to_be_mapped_v2, products_mapped, products_etl_to_be_mapped_v3, etl_4)


print(len(products_etl_to_be_mapped_v3))
print('Done')
# Out:
# 815
# Done

# %%
for product in products_etl_to_be_mapped_v1:
    print(product)
# Out:
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Jambalaya Rice Mix', 'Size': '12\xa0oz', 'itemType': 'Rice/Rice Mix', 'SKU': '42081001', 'BasePrice': '$2.49', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Jambalaya Rice Mix', 'Size': '8\xa0oz', 'itemType': 'Rice/Rice Mix', 'SKU': '42082001', 'BasePrice': '$1.79', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Guacamole Regular', 'Size': '8\xa0oz', 'itemType': '', 'SKU': '42083001', 'BasePrice': '$3.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee Original Blend', 'Size': '12\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42084001', 'BasePrice': '$3.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Italian Dressing', 'Size': '16\xa0oz', 'itemType': 'Salad Dressing', 'SKU': '42086001', 'BasePrice': '$2.00', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Cheeseburger Heat & Serve Sliders', 'Size': '29.28\xa0oz', 'itemType': '', 'SKU': '42087001', 'BasePrice': '$11.59', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Choice Cuts Poultry', 'Size': '36\xa0oz', 'itemType': 'Pet Food', 'SKU': '42088001', 'BasePrice': '$4.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Farmers Pick Concord Grape', 'Size': '46\xa0oz', 'itemType': '', 'SKU': '42089001', 'BasePrice': '$3.59', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Shells & Cheese Microwave Cup', 'Size': '2.39\xa0oz', 'itemType': 'Mac & Cheese', 'SKU': '42092001', 'BasePrice': '$1.00', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Shells & Cheese Original', 'Size': '12\xa0oz', 'itemType': 'Mac & Cheese', 'SKU': '42093001', 'BasePrice': '$2.49', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Iced Tea Lemon', 'Size': '128\xa0oz', 'itemType': '', 'SKU': '42100001', 'BasePrice': '$2.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bagel Thins 100% Whole Wheat', 'Size': '13\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42164001', 'BasePrice': '$2.50', 'meta_code': 2, 'meta_entry': 'Mapped by AU from character match with Bagel'}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bagel Thins Cinnamon Raisin', 'Size': '13\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42165001', 'BasePrice': '$2.50', 'meta_code': 2, 'meta_entry': 'Mapped by AU from character match with Bagel'}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bagel Thins Everything', 'Size': '13\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42166001', 'BasePrice': '$2.50', 'meta_code': 2, 'meta_entry': 'Mapped by AU from character match with Bagel'}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bagel Thins Plain', 'Size': '13\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42167001', 'BasePrice': '$2.50', 'meta_code': 2, 'meta_entry': 'Mapped by AU from character match with Bagel'}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bagels 100% Whole Wheat Mini', 'Size': '20\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42168001', 'BasePrice': '$3.00', 'meta_code': 2, 'meta_entry': 'Mapped by AU from character match with Bagel'}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bagels Blueberry', 'Size': '22\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42169001', 'BasePrice': '$3.00', 'meta_code': 2, 'meta_entry': 'Mapped by AU from character match with Bagel'}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bagels Cinnamon Raisin', 'Size': '22\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42170001', 'BasePrice': '$3.00', 'meta_code': 2, 'meta_entry': 'Mapped by AU from character match with Bagel'}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bagels Cinnamon Raisin Mini', 'Size': '20\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42171001', 'BasePrice': '$3.00', 'meta_code': 2, 'meta_entry': 'Mapped by AU from character match with Bagel'}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bagels Everything', 'Size': '22\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42172001', 'BasePrice': '$3.00', 'meta_code': 2, 'meta_entry': 'Mapped by AU from character match with Bagel'}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bagels Hearty Grains Whole Wheat', 'Size': '22\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42173001', 'BasePrice': '$3.00', 'meta_code': 2, 'meta_entry': 'Mapped by AU from character match with Bagel'}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bagels Plain', 'Size': '22\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42174001', 'BasePrice': '$3.00', 'meta_code': 2, 'meta_entry': 'Mapped by AU from character match with Bagel'}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bagels Plain Mini', 'Size': '20\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42175001', 'BasePrice': '$3.00', 'meta_code': 2, 'meta_entry': 'Mapped by AU from character match with Bagel'}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bagels Plain Whole Grain', 'Size': '22\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42176001', 'BasePrice': '$3.00', 'meta_code': 2, 'meta_entry': 'Mapped by AU from character match with Bagel'}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'English Muffins Double Fiber Honey Wheat', 'Size': '12\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42177001', 'BasePrice': '$3.00', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'English Muffins Hearty Grains 100% Whole Wheat', 'Size': '13\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42178001', 'BasePrice': '$3.00', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'English Muffins Multi Grain Light', 'Size': '12\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42179001', 'BasePrice': '$3.00', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'English Muffins Original', 'Size': '12\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42180001', 'BasePrice': '$2.50', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'English Muffins Original', 'Size': '24\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42181001', 'BasePrice': '$5.49', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'English Muffins Original Whole Grain With Omega 3', 'Size': '12\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42182001', 'BasePrice': '$2.50', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'English Muffins Raisin', 'Size': '13\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42183001', 'BasePrice': '$2.50', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'English Muffins Triple Health', 'Size': '11\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42184001', 'BasePrice': '$3.00', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Cake Dreamies Creme Kakes', 'Size': '14\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42229001', 'BasePrice': '$3.00', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Cake Kandy Kake Peanut Butter', 'Size': '8\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42230001', 'BasePrice': '$3.00', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Cake Koffee Kake Cream Filled', 'Size': '12\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42231001', 'BasePrice': '$3.00', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Cupcakes Buttercream', 'Size': '13.5\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42232001', 'BasePrice': '$3.00', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Cupcakes Chocolate', 'Size': '12.75\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42233001', 'BasePrice': '$3.00', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Cupcakes Krimpet Butterscotch', 'Size': '12\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42234001', 'BasePrice': '$3.00', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Cupcakes Lemon', 'Size': '12.75\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42235001', 'BasePrice': '$3.00', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pie Apple', 'Size': '4\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42236001', 'BasePrice': '$1.00', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pie Cherry', 'Size': '4\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42237001', 'BasePrice': '$1.00', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pie Chocolate Klair', 'Size': '4\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42238001', 'BasePrice': '$1.00', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pie Lemon', 'Size': '4\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42239001', 'BasePrice': '$1.00', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pie Peach', 'Size': '4\xa0oz', 'itemType': 'Baked Goods Other than Bread', 'SKU': '42240001', 'BasePrice': '$1.00', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Hot Cocoa Mix Marshmallows', 'Size': '10\xa0pkg', 'itemType': '', 'SKU': '42241001', 'BasePrice': '$3.09', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Hot Cocoa Mix Milk Chocolate', 'Size': '10\xa0pkg', 'itemType': 'Soda/Juice/Drinks', 'SKU': '42242001', 'BasePrice': '$3.09', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Hot Cocoa Mix Milk Chocolate Canister', 'Size': '28.5\xa0oz', 'itemType': 'Soda/Juice/Drinks', 'SKU': '42243001', 'BasePrice': '$7.69', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Hot Cocoa Mix Milk Chocolate No Sugar Added', 'Size': '8\xa0pkg', 'itemType': 'Soda/Juice/Drinks', 'SKU': '42244001', 'BasePrice': '$3.59', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Sunny Delight Original', 'Size': '6\xa0pkg', 'itemType': '', 'SKU': '42263001', 'BasePrice': '$2.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Orange Citrus Punch Smooth', 'Size': '64\xa0oz', 'itemType': '', 'SKU': '42264001', 'BasePrice': '$2.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Orange Citrus Punch Tangy Original', 'Size': '8\xa0pkg', 'itemType': '', 'SKU': '42265001', 'BasePrice': '$3.89', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bread Raisin', 'Size': '16\xa0oz', 'itemType': 'Bread', 'SKU': '42266001', 'BasePrice': '$3.29', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Giant Bread', 'Size': '24\xa0oz', 'itemType': 'Bread', 'SKU': '42267001', 'BasePrice': '$1.69', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'BBQ Sauce Original', 'Size': '18\xa0oz', 'itemType': '', 'SKU': '42268001', 'BasePrice': '$3.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bread Honey Wheat', 'Size': '22\xa0oz', 'itemType': 'Bread', 'SKU': '42269001', 'BasePrice': '$1.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Stuffing Mix Pork', 'Size': '6\xa0oz', 'itemType': '', 'SKU': '42270001', 'BasePrice': '$2.09', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Lasagna With Meat And Sauce Pasta', 'Size': '38\xa0oz', 'itemType': 'Frozen Food', 'SKU': '42271001', 'BasePrice': '$7.98', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Sandwich Steaks Thin Sliced', 'Size': '21\xa0oz', 'itemType': '', 'SKU': '42272001', 'BasePrice': '$4.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Chunk Light Tuna Water (pouch)', 'Size': '7.06\xa0oz', 'itemType': '', 'SKU': '42278001', 'BasePrice': '$2.29', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee Blonde Veranda', 'Size': '20\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42279001', 'BasePrice': '$14.29', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee Breakfast Blend', 'Size': '12\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42280001', 'BasePrice': '$7.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee Caffe Verona', 'Size': '12\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42281001', 'BasePrice': '$7.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee Caffe Verona Decaf', 'Size': '12\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42282001', 'BasePrice': '$7.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee Caramel', 'Size': '11\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42283001', 'BasePrice': '$7.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee Colombia', 'Size': '12\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42284001', 'BasePrice': '$7.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee Espresso', 'Size': '12\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42285001', 'BasePrice': '$7.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee French Roast', 'Size': '12\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42286001', 'BasePrice': '$7.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee French Roast', 'Size': '20\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42287001', 'BasePrice': '$14.29', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee Gold Coast Blend', 'Size': '12\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42288001', 'BasePrice': '$7.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee House Blend', 'Size': '12\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42289001', 'BasePrice': '$7.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee House Blend', 'Size': '20\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42290001', 'BasePrice': '$14.29', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee House Blend Decaf', 'Size': '12\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42291001', 'BasePrice': '$7.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee Italian', 'Size': '12\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42292001', 'BasePrice': '$7.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee Mocha', 'Size': '11\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42293001', 'BasePrice': '$7.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee Pike Place', 'Size': '12\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42294001', 'BasePrice': '$7.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee Sumatra', 'Size': '12\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42295001', 'BasePrice': '$7.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee Veranda Blend', 'Size': '12\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42296001', 'BasePrice': '$7.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee Willow Blend', 'Size': '12\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42297001', 'BasePrice': '$7.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee Willow Blend Decaf', 'Size': '12\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42298001', 'BasePrice': '$7.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Hot Cocoa Mix Premium Double Chocolate', 'Size': '8\xa0pkg', 'itemType': '', 'SKU': '42299001', 'BasePrice': '$6.59', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Hot Cocoa Mix Salted Caramel', 'Size': '8\xa0pkg', 'itemType': '', 'SKU': '42300001', 'BasePrice': '$6.59', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Hot Cocoa Mix Vanilla Brulee', 'Size': '8\xa0pkg', 'itemType': '', 'SKU': '42301001', 'BasePrice': '$6.59', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Vinegar Balsamic', 'Size': '8.5\xa0oz', 'itemType': '', 'SKU': '42302001', 'BasePrice': '$2.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Sparkling Spring Water Pomegranate Berry', 'Size': '17\xa0oz', 'itemType': '', 'SKU': '42303001', 'BasePrice': '$1.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Soy Milk Vanilla', 'Size': '32\xa0oz', 'itemType': 'Soda/Juice/Drinks', 'SKU': '42304001', 'BasePrice': '$4.79', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Baby Lotion Original', 'Size': '1\xa0ct', 'itemType': '', 'SKU': '42305001', 'BasePrice': '$2.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Hair Moist Creme', 'Size': '4\xa0oz', 'itemType': '', 'SKU': '42306001', 'BasePrice': '$3.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Hair Moisturizer Detangling', 'Size': '12\xa0oz', 'itemType': '', 'SKU': '42307001', 'BasePrice': '$3.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Tortilla Chips Original', 'Size': '16\xa0oz', 'itemType': '', 'SKU': '42308001', 'BasePrice': '$2.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Singles To Go Diet Green Tea', 'Size': '6\xa0ct', 'itemType': '', 'SKU': '42309001', 'BasePrice': '$0.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Singles To Go Diet Lemon', 'Size': '6\xa0ct', 'itemType': '', 'SKU': '42310001', 'BasePrice': '$0.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Jam Grape', 'Size': '18\xa0oz', 'itemType': 'Jelly/Jam', 'SKU': '42311001', 'BasePrice': '$2.29', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Jam Strawberry', 'Size': '18\xa0oz', 'itemType': 'Jelly/Jam', 'SKU': '42312001', 'BasePrice': '$3.09', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Jelly Grape', 'Size': '18\xa0oz', 'itemType': 'Jelly/Jam', 'SKU': '42313001', 'BasePrice': '$2.29', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Squeeze Jelly Grape', 'Size': '20\xa0oz', 'itemType': 'Jelly/Jam', 'SKU': '42314001', 'BasePrice': '$2.14', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pasta Sauce Tomato Basil', 'Size': '25\xa0oz', 'itemType': 'Gravy/Sauce', 'SKU': '42317001', 'BasePrice': '$1.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Almond Milk Original', 'Size': '.5\xa0gal', 'itemType': 'Soda/Juice/Drinks', 'SKU': '42318001', 'BasePrice': '$3.69', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Soymilk Light Chocolate', 'Size': '64\xa0oz', 'itemType': 'Soda/Juice/Drinks', 'SKU': '42319001', 'BasePrice': '$3.69', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee Level 3', 'Size': '12\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42324001', 'BasePrice': '$6.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee Level 4', 'Size': '12\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42325001', 'BasePrice': '$6.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee Level 5', 'Size': '12\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42326001', 'BasePrice': '$6.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'All Purpose Cleaner Bleach 5-in-1', 'Size': '32\xa0oz', 'itemType': '', 'SKU': '42327001', 'BasePrice': '$3.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Shower Automatic Refill Liquid Shower Cleaner', 'Size': '34\xa0oz', 'itemType': '', 'SKU': '42328001', 'BasePrice': '$9.00', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Sponges Blue', 'Size': '3\xa0pkg', 'itemType': '', 'SKU': '42329001', 'BasePrice': '$2.49', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'English Muffins Original', 'Size': '12\xa0oz', 'itemType': '', 'SKU': '42330001', 'BasePrice': '$1.49', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bread Amazin Raisin', 'Size': '20\xa0oz', 'itemType': 'Bread', 'SKU': '42331001', 'BasePrice': '$4.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Tastings Medium Asiago', 'Size': '3.25\xa0oz', 'itemType': '', 'SKU': '42332001', 'BasePrice': '$2.79', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Tastings Parmentino', 'Size': '3.75\xa0oz', 'itemType': '', 'SKU': '42333001', 'BasePrice': '$2.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Flatbread Angus Cheeseburgers', 'Size': '4\xa0ct', 'itemType': 'Bread', 'SKU': '42334001', 'BasePrice': '$2.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Flatbread Chicken Melts', 'Size': '4\xa0ct', 'itemType': 'Bread', 'SKU': '42335001', 'BasePrice': '$2.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee 100% Colombian', 'Size': '11\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42337001', 'BasePrice': '$3.29', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee 100% Colombian', 'Size': '34.5\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42338001', 'BasePrice': '$6.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee Classic Decaf', 'Size': '13\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42339001', 'BasePrice': '$3.79', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee Classic Decaf', 'Size': '22.6\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42340001', 'BasePrice': '$6.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee Classic Regular', 'Size': '11.5\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42341001', 'BasePrice': '$3.29', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee Classic Regular', 'Size': '31.5\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42342001', 'BasePrice': '$6.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee French Roast', 'Size': '11.5\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42343001', 'BasePrice': '$3.29', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee French Roast', 'Size': '33\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42344001', 'BasePrice': '$6.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee Half The Caffeine', 'Size': '11.5\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42345001', 'BasePrice': '$3.29', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bread Raisin', 'Size': '16\xa0oz', 'itemType': 'Bread', 'SKU': '42349001', 'BasePrice': '$2.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bread Texas Toast', 'Size': '24\xa0oz', 'itemType': 'Bread', 'SKU': '42350001', 'BasePrice': '$2.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee Breakfast Blend', 'Size': '12\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42351001', 'BasePrice': '$5.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee Buttery Caramel', 'Size': '12\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42352001', 'BasePrice': '$5.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coffee Half Caf French', 'Size': '11\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42353001', 'BasePrice': '$5.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Juice Just Black Cherry', 'Size': '32\xa0oz', 'itemType': '', 'SKU': '42354001', 'BasePrice': '$8.69', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Sugar White', 'Size': '4\xa0lbs', 'itemType': '', 'SKU': '42362001', 'BasePrice': '$1.69', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Honey Wheat Rods Pretzels', 'Size': '10\xa0oz', 'itemType': 'Snacks', 'SKU': '42363001', 'BasePrice': '$3.29', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Peanut Butter Cups King Size', 'Size': '2.8\xa0oz', 'itemType': 'Candy', 'SKU': '42364001', 'BasePrice': '$1.69', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Stone Wheat Thins Original', 'Size': '10.6\xa0oz', 'itemType': 'Snacks', 'SKU': '42383001', 'BasePrice': '$4.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Just Black Cherry Juice', 'Size': '32\xa0oz', 'itemType': '', 'SKU': '42384001', 'BasePrice': '$3.35', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Apple Nut Harvest Real Medley Bars', 'Size': '6.7\xa0oz', 'itemType': 'Snacks', 'SKU': '42387001', 'BasePrice': '$3.50', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Cherry Pistachio Real Medley Bars', 'Size': '6.7\xa0oz', 'itemType': 'Snacks', 'SKU': '42388001', 'BasePrice': '$3.50', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Granola Bars Chewy Chocolate Chip', 'Size': '6\xa0pkg', 'itemType': 'Snacks', 'SKU': '42389001', 'BasePrice': '$2.50', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Peach Almond Real Medley Bars', 'Size': '6.7\xa0oz', 'itemType': 'Snacks', 'SKU': '42393001', 'BasePrice': '$3.50', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Yogurt Strawberry Chewy Granola Bars', 'Size': '6.1\xa0oz', 'itemType': 'Snacks', 'SKU': '42394001', 'BasePrice': '$2.50', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Sausage Pork', 'Size': '1\xa0lbs', 'itemType': '', 'SKU': '42395001', 'BasePrice': '$3.29', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Lettuce Head', 'Size': '1\xa0ct', 'itemType': 'Produce', 'SKU': '42396001', 'BasePrice': '$1.09', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Turnip Greens Vegetables', 'Size': '1\xa0lbs', 'itemType': 'Produce', 'SKU': '42397001', 'BasePrice': '$1.29', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Mocha Coffee', 'Size': '12\xa0oz', 'itemType': 'Coffee/Creamer', 'SKU': '42398001', 'BasePrice': '$4.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bacon Potato Crisps', 'Size': '5.6\xa0oz', 'itemType': 'Snacks', 'SKU': '42399001', 'BasePrice': '$1.67', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'BBQ Grab & Go', 'Size': '2.5\xa0oz', 'itemType': 'Snacks', 'SKU': '42400001', 'BasePrice': '$1.00', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'BBQ Potato Crisps', 'Size': '5.5\xa0oz', 'itemType': 'Snacks', 'SKU': '42401001', 'BasePrice': '$1.67', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Buffalo Ranch Potato Crisps', 'Size': '5.5\xa0oz', 'itemType': 'Snacks', 'SKU': '42402001', 'BasePrice': '$1.67', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Cheddar & Sour Cream Potato Crisps', 'Size': '5.5\xa0oz', 'itemType': 'Snacks', 'SKU': '42403001', 'BasePrice': '$1.67', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Cheddar Cheese Grab & Go', 'Size': '2.5\xa0oz', 'itemType': 'Snacks', 'SKU': '42404001', 'BasePrice': '$1.00', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Cheddar Cheese Potato Crisps', 'Size': '5.5\xa0oz', 'itemType': 'Snacks', 'SKU': '42405001', 'BasePrice': '$1.67', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Cheese Burger Potato Crisps', 'Size': '5.5\xa0oz', 'itemType': 'Snacks', 'SKU': '42406001', 'BasePrice': '$1.67', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Honey Butter Stix', 'Size': '4.88\xa0oz', 'itemType': 'Snacks', 'SKU': '42407001', 'BasePrice': '$3.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Honey Mustard Potato Crisps', 'Size': '5.5\xa0oz', 'itemType': 'Snacks', 'SKU': '42408001', 'BasePrice': '$1.67', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Jalapeno Potato Crisps', 'Size': '5.5\xa0oz', 'itemType': 'Snacks', 'SKU': '42409001', 'BasePrice': '$1.67', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Lightly Salted Cheddar Cheese Potato Crisps', 'Size': '5.5\xa0oz', 'itemType': 'Snacks', 'SKU': '42410001', 'BasePrice': '$1.67', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Lightly Salted Potato Crisps', 'Size': '5.5\xa0oz', 'itemType': 'Snacks', 'SKU': '42411001', 'BasePrice': '$1.67', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Loaded Baked Potato Potato Crisps', 'Size': '5.5\xa0oz', 'itemType': 'Snacks', 'SKU': '42412001', 'BasePrice': '$1.67', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Loud Fiery Chili Lime Corn Crisps', 'Size': '5.4\xa0oz', 'itemType': 'Snacks', 'SKU': '42413001', 'BasePrice': '$1.67', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Loud Mighty Margherita Pizza Grain & Vegetable Crisps', 'Size': '5.1\xa0oz', 'itemType': 'Snacks', 'SKU': '42414001', 'BasePrice': '$1.67', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Loud Salsa Fiesta Corn Crisps', 'Size': '5.4\xa0oz', 'itemType': 'Snacks', 'SKU': '42415001', 'BasePrice': '$1.67', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Loud Spicy Queso Corn Crisps', 'Size': '5.4\xa0oz', 'itemType': 'Snacks', 'SKU': '42416001', 'BasePrice': '$1.67', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Loud Super Cheesy Italian Grain & Vegetable Crisps', 'Size': '5.1\xa0oz', 'itemType': 'Snacks', 'SKU': '42417001', 'BasePrice': '$1.67', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Memphis BBQ Potato Crisps', 'Size': '5.5\xa0oz', 'itemType': 'Snacks', 'SKU': '42418001', 'BasePrice': '$1.67', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Mixed Flavors Snack Stacks', 'Size': '24\xa0ct', 'itemType': 'Snacks', 'SKU': '42419001', 'BasePrice': '$9.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Original Fat Free Potato Chips', 'Size': '5.43\xa0oz', 'itemType': 'Snacks', 'SKU': '42420001', 'BasePrice': '$2.98', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Original Grab & Go', 'Size': '2.36\xa0oz', 'itemType': 'Snacks', 'SKU': '42421001', 'BasePrice': '$1.00', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Original Potato Crisps', 'Size': '12\xa0ct', 'itemType': 'Snacks', 'SKU': '42422001', 'BasePrice': '$5.29', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Original Potato Crisps', 'Size': '5.2\xa0oz', 'itemType': 'Snacks', 'SKU': '42423001', 'BasePrice': '$1.67', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pizza Potato Crisps', 'Size': '5.5\xa0oz', 'itemType': 'Snacks', 'SKU': '42424001', 'BasePrice': '$1.67', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pizza Stix', 'Size': '4.88\xa0ct', 'itemType': 'Snacks', 'SKU': '42425001', 'BasePrice': '$3.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Ranch Potato Crisps', 'Size': '5.5\xa0oz', 'itemType': 'Snacks', 'SKU': '42426001', 'BasePrice': '$1.67', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Reduced Fat Potato Crisps', 'Size': '5.5\xa0oz', 'itemType': 'Snacks', 'SKU': '42427001', 'BasePrice': '$1.67', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Reduced Fat Sour Cream & Onion Potato Crisps', 'Size': '5.2\xa0oz', 'itemType': 'Snacks', 'SKU': '42428001', 'BasePrice': '$1.67', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Salt & Vinegar Potato Crisps', 'Size': '5.5\xa0oz', 'itemType': 'Snacks', 'SKU': '42429001', 'BasePrice': '$1.67', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Screamin Dill Pickle Potato Crisps', 'Size': '5.5\xa0oz', 'itemType': 'Snacks', 'SKU': '42430001', 'BasePrice': '$1.67', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Sour Cream & Onion Grab & Go', 'Size': '2.5\xa0oz', 'itemType': 'Snacks', 'SKU': '42431001', 'BasePrice': '$1.00', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Sour Cream & Onion Potato Crisps', 'Size': '5.5\xa0oz', 'itemType': 'Snacks', 'SKU': '42432001', 'BasePrice': '$1.67', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Sour Cream & Onion Stacks', 'Size': '12\xa0ct', 'itemType': 'Snacks', 'SKU': '42433001', 'BasePrice': '$5.00', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Variety Pack Grab & Go', 'Size': '15\xa0ct', 'itemType': 'Snacks', 'SKU': '42434001', 'BasePrice': '$8.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Zero Fruit Punch', 'Size': '32\xa0oz', 'itemType': '', 'SKU': '42435001', 'BasePrice': '$0.89', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Zero Grape', 'Size': '32\xa0oz', 'itemType': '', 'SKU': '42436001', 'BasePrice': '$0.89', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Zero Mixed Berry', 'Size': '32\xa0oz', 'itemType': '', 'SKU': '42437001', 'BasePrice': '$0.89', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Zero Orange', 'Size': '32\xa0oz', 'itemType': '', 'SKU': '42438001', 'BasePrice': '$0.89', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Grands Biscuits Buttermilk', 'Size': '20\xa0ct', 'itemType': 'Other Dairy/Not Milk', 'SKU': '42480001', 'BasePrice': '$3.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Grands Biscuits Flaky Layers Buttermilk', 'Size': '16.3\xa0oz', 'itemType': 'Other Dairy/Not Milk', 'SKU': '42481001', 'BasePrice': '$1.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Grands Biscuits Southern Homestyle Buttermilk', 'Size': '10.2\xa0oz', 'itemType': 'Other Dairy/Not Milk', 'SKU': '42482001', 'BasePrice': '$1.59', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Grands Biscuits Southern Homestyle Buttermilk', 'Size': '16.3\xa0oz', 'itemType': 'Other Dairy/Not Milk', 'SKU': '42483001', 'BasePrice': '$1.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Grands Junior Biscuits Flaky Layers Buttermilk', 'Size': '6\xa0oz', 'itemType': 'Other Dairy/Not Milk', 'SKU': '42484001', 'BasePrice': '$1.29', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Hamburgers Pure Beef', 'Size': '32\xa0oz', 'itemType': '', 'SKU': '42509001', 'BasePrice': '$9.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Hamburgers Pure Beef', 'Size': '64\xa0oz', 'itemType': '', 'SKU': '42510001', 'BasePrice': '$19.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Evaporated Milk Original', 'Size': '12\xa0oz', 'itemType': 'Baking Supplies', 'SKU': '42511001', 'BasePrice': '$1.79', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bagels Everything', 'Size': '6\xa0ct', 'itemType': '', 'SKU': '42514001', 'BasePrice': '$4.29', 'meta_code': 2, 'meta_entry': 'Mapped by AU from character match with Bagel'}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bagels Mini/Brown Sugar Cinnamon', 'Size': '17\xa0oz', 'itemType': '', 'SKU': '42515001', 'BasePrice': '$4.29', 'meta_code': 2, 'meta_entry': 'Mapped by AU from character match with Bagel'}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bagels Mini/Cinnamon Raisin', 'Size': '12\xa0ct', 'itemType': '', 'SKU': '42516001', 'BasePrice': '$4.29', 'meta_code': 2, 'meta_entry': 'Mapped by AU from character match with Bagel'}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bagels Mini/Plain', 'Size': '17\xa0oz', 'itemType': '', 'SKU': '42517001', 'BasePrice': '$4.29', 'meta_code': 2, 'meta_entry': 'Mapped by AU from character match with Bagel'}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bagels Mini/Whole Wheat', 'Size': '12\xa0ct', 'itemType': '', 'SKU': '42518001', 'BasePrice': '$4.29', 'meta_code': 2, 'meta_entry': 'Mapped by AU from character match with Bagel'}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bagels Pre-Sliced/Plain', 'Size': '21\xa0oz', 'itemType': '', 'SKU': '42519001', 'BasePrice': '$4.29', 'meta_code': 2, 'meta_entry': 'Mapped by AU from character match with Bagel'}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bread Cinnamon Swirl', 'Size': '16\xa0oz', 'itemType': 'Bread', 'SKU': '42520001', 'BasePrice': '$3.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bread Swirl Brown Sugar Cinnamon', 'Size': '16\xa0oz', 'itemType': 'Bread', 'SKU': '42521001', 'BasePrice': '$3.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bread Swirl Raisin Cinnamon', 'Size': '16\xa0oz', 'itemType': 'Bread', 'SKU': '42522001', 'BasePrice': '$3.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bread White Original', 'Size': '16\xa0oz', 'itemType': 'Bread', 'SKU': '42523001', 'BasePrice': '$3.49', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bread White Sandwich', 'Size': '16\xa0oz', 'itemType': 'Bread', 'SKU': '42524001', 'BasePrice': '$3.49', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Bread Whole Wheat Cinnamon Swirl', 'Size': '16\xa0oz', 'itemType': 'Bread', 'SKU': '42525001', 'BasePrice': '$3.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Farmhouse Bread Hearty White', 'Size': '24\xa0oz', 'itemType': 'Bread', 'SKU': '42526001', 'BasePrice': '$3.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Farmhouse Bread Oatmeal', 'Size': '24\xa0oz', 'itemType': 'Bread', 'SKU': '42527001', 'BasePrice': '$3.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Farmhouse Bread Potato', 'Size': '22\xa0oz', 'itemType': 'Bread', 'SKU': '42528001', 'BasePrice': '$3.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Farmhouse Bread Sourdough', 'Size': '24\xa0oz', 'itemType': 'Bread', 'SKU': '42529001', 'BasePrice': '$3.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Baby Cheddar', 'Size': '7.2\xa0oz', 'itemType': '', 'SKU': '42530001', 'BasePrice': '$2.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Blasted Burstin BBQ', 'Size': '6.6\xa0oz', 'itemType': '', 'SKU': '42531001', 'BasePrice': '$2.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Blasted Cheddar', 'Size': '9\xa0pkg', 'itemType': '', 'SKU': '42532001', 'BasePrice': '$5.49', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Blasted Slammin Sour Cream & Onion', 'Size': '6.6\xa0oz', 'itemType': '', 'SKU': '42533001', 'BasePrice': '$2.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Blasted Xplosive Pizza', 'Size': '6.6\xa0oz', 'itemType': '', 'SKU': '42534001', 'BasePrice': '$2.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Blasted Xtra Cheddar', 'Size': '11\xa0oz', 'itemType': '', 'SKU': '42535001', 'BasePrice': '$3.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Blasted Xtra Cheddar', 'Size': '30\xa0oz', 'itemType': '', 'SKU': '42536001', 'BasePrice': '$8.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Blasted Xtra Cheddar', 'Size': '6.6\xa0oz', 'itemType': '', 'SKU': '42537001', 'BasePrice': '$2.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Cheddar', 'Size': '2\xa0oz', 'itemType': '', 'SKU': '42538001', 'BasePrice': '$1.09', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Cheddar', 'Size': '20\xa0ct', 'itemType': '', 'SKU': '42539001', 'BasePrice': '$8.69', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Cheddar', 'Size': '6.6\xa0oz', 'itemType': '', 'SKU': '42540001', 'BasePrice': '$2.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Cheddar Colors', 'Size': '6.6\xa0oz', 'itemType': '', 'SKU': '42541001', 'BasePrice': '$2.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Grahams Cookies And Creme', 'Size': '6.6\xa0oz', 'itemType': '', 'SKU': '42542001', 'BasePrice': '$2.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Grahams Smores', 'Size': '6.6\xa0oz', 'itemType': '', 'SKU': '42543001', 'BasePrice': '$2.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Grahams Vanilla Cupcake', 'Size': '6.6\xa0oz', 'itemType': '', 'SKU': '42544001', 'BasePrice': '$2.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Mix Extra Cheddar & Pretzel', 'Size': '34\xa0oz', 'itemType': '', 'SKU': '42545001', 'BasePrice': '$8.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Mix Extra Cheddar + Pretzel', 'Size': '6\xa0oz', 'itemType': '', 'SKU': '42546001', 'BasePrice': '$2.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Mix Honey Mustard + Pretzel', 'Size': '6\xa0oz', 'itemType': '', 'SKU': '42547001', 'BasePrice': '$2.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Organic Wheat Cheddar Lunch Packs', 'Size': '9\xa0pkg', 'itemType': '', 'SKU': '42548001', 'BasePrice': '$5.49', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Parmesan', 'Size': '6.6\xa0oz', 'itemType': '', 'SKU': '42549001', 'BasePrice': '$2.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Pizza', 'Size': '6.6\xa0oz', 'itemType': '', 'SKU': '42550001', 'BasePrice': '$2.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Pretzel', 'Size': '8\xa0oz', 'itemType': '', 'SKU': '42551001', 'BasePrice': '$2.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Princess', 'Size': '2\xa0oz', 'itemType': '', 'SKU': '42552001', 'BasePrice': '$1.09', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Princess', 'Size': '6.6\xa0oz', 'itemType': '', 'SKU': '42553001', 'BasePrice': '$2.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Saltine', 'Size': '6.6\xa0oz', 'itemType': '', 'SKU': '42554001', 'BasePrice': '$2.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Sweet & Savory', 'Size': '20\xa0ct', 'itemType': '', 'SKU': '42555001', 'BasePrice': '$8.69', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Whole Grain Cheddar', 'Size': '6.6\xa0oz', 'itemType': '', 'SKU': '42556001', 'BasePrice': '$2.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Whole Grain Cheddar Colors', 'Size': '6.6\xa0oz', 'itemType': '', 'SKU': '42557001', 'BasePrice': '$2.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Whole Grain Cinnamon', 'Size': '6.6\xa0oz', 'itemType': '', 'SKU': '42558001', 'BasePrice': '$2.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Whole Grain Honey Grahams', 'Size': '6.6\xa0oz', 'itemType': '', 'SKU': '42559001', 'BasePrice': '$2.19', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Goldfish Whole Grain Pretzel', 'Size': '8\xa0oz', 'itemType': '', 'SKU': '42560001', 'BasePrice': '$2.19', 'meta_code': -1, 'meta_entry': ''}
# ...
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Hamburger Helper Potatoes Stroganoff', 'Size': '5\xa0oz', 'itemType': 'Pasta/Noodles', 'SKU': '43976001', 'BasePrice': '$1.29', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Hamburger Helper Salisbury', 'Size': '6.2\xa0oz', 'itemType': 'Pasta/Noodles', 'SKU': '43977001', 'BasePrice': '$1.29', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Hamburger Helper Stroganoff', 'Size': '6.4\xa0oz', 'itemType': 'Pasta/Noodles', 'SKU': '43978001', 'BasePrice': '$1.29', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Hamburger Helper Three Cheese', 'Size': '6\xa0oz', 'itemType': 'Pasta/Noodles', 'SKU': '43979001', 'BasePrice': '$1.29', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Collezione Bucatini', 'Size': '12\xa0oz', 'itemType': 'Pasta/Noodles', 'SKU': '44059001', 'BasePrice': '$2.59', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Gluten Free Elbows', 'Size': '12\xa0oz', 'itemType': 'Pasta/Noodles', 'SKU': '44060001', 'BasePrice': '$2.59', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Gluten Free Penne', 'Size': '12\xa0oz', 'itemType': 'Pasta/Noodles', 'SKU': '44061001', 'BasePrice': '$2.59', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Gluten Free Spaghetti', 'Size': '12\xa0oz', 'itemType': 'Pasta/Noodles', 'SKU': '44062001', 'BasePrice': '$2.59', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pasta Angel Hair', 'Size': '1\xa0lbs', 'itemType': 'Pasta/Noodles', 'SKU': '44063001', 'BasePrice': '$1.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pasta Elbows', 'Size': '1\xa0lbs', 'itemType': 'Pasta/Noodles', 'SKU': '44064001', 'BasePrice': '$1.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pasta Farfalle', 'Size': '1\xa0lbs', 'itemType': 'Pasta/Noodles', 'SKU': '44065001', 'BasePrice': '$1.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pasta Fettuccine', 'Size': '1\xa0lbs', 'itemType': 'Pasta/Noodles', 'SKU': '44066001', 'BasePrice': '$1.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pasta Fideo Cut Spaghetti', 'Size': '1\xa0lbs', 'itemType': 'Pasta/Noodles', 'SKU': '44067001', 'BasePrice': '$1.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pasta Jumbo Shells', 'Size': '12\xa0oz', 'itemType': 'Pasta/Noodles', 'SKU': '44068001', 'BasePrice': '$2.29', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pasta Linguine', 'Size': '1\xa0lbs', 'itemType': 'Pasta/Noodles', 'SKU': '44069001', 'BasePrice': '$1.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pasta Mini Penne', 'Size': '1\xa0lbs', 'itemType': 'Pasta/Noodles', 'SKU': '44070001', 'BasePrice': '$1.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pasta Mostaccioli', 'Size': '1\xa0lbs', 'itemType': 'Pasta/Noodles', 'SKU': '44071001', 'BasePrice': '$1.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pasta Orzo', 'Size': '1\xa0lbs', 'itemType': 'Pasta/Noodles', 'SKU': '44072001', 'BasePrice': '$1.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pasta Penne', 'Size': '1\xa0lbs', 'itemType': 'Pasta/Noodles', 'SKU': '44073001', 'BasePrice': '$1.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pasta Rigatoni', 'Size': '1\xa0lbs', 'itemType': 'Pasta/Noodles', 'SKU': '44074001', 'BasePrice': '$1.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pasta Rotini', 'Size': '1\xa0lbs', 'itemType': 'Pasta/Noodles', 'SKU': '44075001', 'BasePrice': '$1.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pasta Spaghetti', 'Size': '1\xa0lbs', 'itemType': 'Pasta/Noodles', 'SKU': '44076001', 'BasePrice': '$1.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pasta Thick Spaghetti', 'Size': '1\xa0lbs', 'itemType': 'Pasta/Noodles', 'SKU': '44077001', 'BasePrice': '$1.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pasta Thin Spaghetti', 'Size': '1\xa0lbs', 'itemType': 'Pasta/Noodles', 'SKU': '44078001', 'BasePrice': '$1.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pasta Tri-Color Rotini', 'Size': '12\xa0oz', 'itemType': 'Pasta/Noodles', 'SKU': '44079001', 'BasePrice': '$1.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pasta Veggie Rotini', 'Size': '12\xa0oz', 'itemType': 'Pasta/Noodles', 'SKU': '44080001', 'BasePrice': '$1.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pasta Wavy Lasagne', 'Size': '1\xa0lbs', 'itemType': 'Pasta/Noodles', 'SKU': '44081001', 'BasePrice': '$2.29', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'PLUS Multigrain Elbows', 'Size': '14.5\xa0oz', 'itemType': 'Pasta/Noodles', 'SKU': '44082001', 'BasePrice': '$1.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pronto Elbows', 'Size': '12\xa0oz', 'itemType': 'Pasta/Noodles', 'SKU': '44083001', 'BasePrice': '$1.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pronto Penne', 'Size': '12\xa0oz', 'itemType': 'Pasta/Noodles', 'SKU': '44084001', 'BasePrice': '$1.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pronto Rotini', 'Size': '12\xa0oz', 'itemType': 'Pasta/Noodles', 'SKU': '44085001', 'BasePrice': '$1.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Pronto Spaghetti', 'Size': '12\xa0oz', 'itemType': 'Pasta/Noodles', 'SKU': '44086001', 'BasePrice': '$1.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Protein Plus Multigrain Angel Hair', 'Size': '14.5\xa0oz', 'itemType': 'Pasta/Noodles', 'SKU': '44087001', 'BasePrice': '$2.59', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Protein Plus Multigrain Penne', 'Size': '14.5\xa0oz', 'itemType': 'Pasta/Noodles', 'SKU': '44088001', 'BasePrice': '$2.59', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Protein Plus Multigrain Thin Spaghetti', 'Size': '14.5\xa0oz', 'itemType': 'Pasta/Noodles', 'SKU': '44089001', 'BasePrice': '$2.59', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Sauce Creamy Alfredo', 'Size': '14.5\xa0oz', 'itemType': 'Gravy/Sauce', 'SKU': '44090001', 'BasePrice': '$2.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Sauce Garlic Alfredo', 'Size': '14.5\xa0oz', 'itemType': 'Gravy/Sauce', 'SKU': '44091001', 'BasePrice': '$2.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Sauce Marinara', 'Size': '24\xa0oz', 'itemType': 'Gravy/Sauce', 'SKU': '44092001', 'BasePrice': '$2.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Sauce Meat', 'Size': '24\xa0oz', 'itemType': 'Gravy/Sauce', 'SKU': '44093001', 'BasePrice': '$2.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Sauce Roasted Garlic', 'Size': '24\xa0oz', 'itemType': 'Gravy/Sauce', 'SKU': '44094001', 'BasePrice': '$2.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Sauce Tomato & Basil', 'Size': '24\xa0oz', 'itemType': 'Gravy/Sauce', 'SKU': '44095001', 'BasePrice': '$2.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Sauce Traditional', 'Size': '24\xa0oz', 'itemType': 'Gravy/Sauce', 'SKU': '44096001', 'BasePrice': '$2.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'White Fiber Shells', 'Size': '12\xa0oz', 'itemType': 'Pasta/Noodles', 'SKU': '44097001', 'BasePrice': '$1.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'White Fiber Spaghetti', 'Size': '12\xa0oz', 'itemType': 'Pasta/Noodles', 'SKU': '44098001', 'BasePrice': '$1.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Whole Grain Lasagne', 'Size': '13.25\xa0oz', 'itemType': 'Pasta/Noodles', 'SKU': '44099001', 'BasePrice': '$2.29', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Whole Grain Linguine', 'Size': '1\xa0lbs', 'itemType': 'Pasta/Noodles', 'SKU': '44100001', 'BasePrice': '$1.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Whole Grain Penne', 'Size': '1\xa0lbs', 'itemType': 'Pasta/Noodles', 'SKU': '44101001', 'BasePrice': '$1.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Whole Grain Rotini', 'Size': '1\xa0lbs', 'itemType': 'Pasta/Noodles', 'SKU': '44102001', 'BasePrice': '$1.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Whole Grain Spaghetti', 'Size': '1\xa0lbs', 'itemType': 'Pasta/Noodles', 'SKU': '44103001', 'BasePrice': '$1.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Whole Grain Thin Spaghetti', 'Size': '1\xa0lbs', 'itemType': 'Pasta/Noodles', 'SKU': '44104001', 'BasePrice': '$1.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Chicken Breast Stuffed Broccoli & Cheese', 'Size': '2.5\xa0oz', 'itemType': '', 'SKU': '44105001', 'BasePrice': '$5.49', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Brown N Serve Sausage Maple Links', 'Size': '6.4\xa0oz', 'itemType': 'Frozen Food', 'SKU': '44106001', 'BasePrice': '$1.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Brown N Serve Sausage Original Links', 'Size': '6.4\xa0oz', 'itemType': 'Frozen Food', 'SKU': '44107001', 'BasePrice': '$1.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Brown N Serve Sausage Turkey', 'Size': '6.4\xa0oz', 'itemType': 'Frozen Food', 'SKU': '44108001', 'BasePrice': '$1.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Chicken Breast Strips', 'Size': '24\xa0oz', 'itemType': '', 'SKU': '44109001', 'BasePrice': '$4.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Chicken Patties', 'Size': '27\xa0oz', 'itemType': '', 'SKU': '44110001', 'BasePrice': '$4.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Chicken Patty', 'Size': '27\xa0oz', 'itemType': '', 'SKU': '44111001', 'BasePrice': '$4.39', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Scramble Bacon', 'Size': '6.5\xa0oz', 'itemType': 'Frozen Food', 'SKU': '44119001', 'BasePrice': '$3.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Scramble Farmhouse-Style Sausage', 'Size': '7\xa0oz', 'itemType': 'Frozen Food', 'SKU': '44120001', 'BasePrice': '$3.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coconut Milk Lite', 'Size': '13.5\xa0oz', 'itemType': 'Drink', 'SKU': '44121001', 'BasePrice': '$2.29', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Sandwich Thins Honey Wheat', 'Size': '12\xa0oz', 'itemType': 'Bread', 'SKU': '44122001', 'BasePrice': '$3.49', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Sandwich Thins Multigrain', 'Size': '12\xa0oz', 'itemType': 'Bread', 'SKU': '44123001', 'BasePrice': '$3.49', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Sandwich Thins Potato Rolls', 'Size': '12\xa0oz', 'itemType': 'Bread', 'SKU': '44124001', 'BasePrice': '$3.49', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Sandwich Thins Whole Wheat', 'Size': '12\xa0oz', 'itemType': 'Bread', 'SKU': '44125001', 'BasePrice': '$3.49', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Fruitables Berry Berry Juice', 'Size': '8\xa0ct', 'itemType': '', 'SKU': '44126001', 'BasePrice': '$3.29', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Drink Mix Spiced Cider', 'Size': '10\xa0pkg', 'itemType': 'Drink', 'SKU': '44147001', 'BasePrice': '$3.59', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Almond Milk Original', 'Size': '.5\xa0gal', 'itemType': 'Drink', 'SKU': '44148001', 'BasePrice': '$3.69', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Almond Milk Unsweetened', 'Size': '32\xa0oz', 'itemType': 'Drink', 'SKU': '44149001', 'BasePrice': '$3.59', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Almond Milk Vanilla', 'Size': '.5\xa0gal', 'itemType': 'Drink', 'SKU': '44150001', 'BasePrice': '$3.69', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Snack Cakes Vanilla', 'Size': '6\xa0ct', 'itemType': 'Snacks', 'SKU': '44151001', 'BasePrice': '$6.59', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Laundry Detergent 2X Ultra Free Clear', 'Size': '50\xa0oz', 'itemType': 'Household', 'SKU': '44152001', 'BasePrice': '$11.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Gourmet Griller Carmelized Onion', 'Size': '28\xa0oz', 'itemType': 'Frozen Food', 'SKU': '44153001', 'BasePrice': '$10.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Gourmet Griller Sweet Italian', 'Size': '28\xa0oz', 'itemType': 'Frozen Food', 'SKU': '44154001', 'BasePrice': '$10.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Meatballs Caramelized Onion', 'Size': '12\xa0oz', 'itemType': 'Frozen Food', 'SKU': '44155001', 'BasePrice': '$6.59', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Meatballs Pineapple Teriyaki', 'Size': '12\xa0oz', 'itemType': 'Frozen Food', 'SKU': '44156001', 'BasePrice': '$6.59', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Meatballs Sundried Tomato', 'Size': '12\xa0oz', 'itemType': 'Frozen Food', 'SKU': '44157001', 'BasePrice': '$6.59', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Popcorn Butter', 'Size': '6\xa0pkg', 'itemType': 'Frozen Food', 'SKU': '44158001', 'BasePrice': '$3.99', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Coconut Milk Unsweetened', 'Size': '13.5\xa0oz', 'itemType': 'Drink', 'SKU': '44159001', 'BasePrice': '$3.59', 'meta_code': -1, 'meta_entry': ''}
# {'Manufacturer': 'Rowan Warehouse', 'Product Name': 'Iced Tea Mix Regular', 'Size': '53\xa0oz', 'itemType': 'Drink', 'SKU': '44160001', 'BasePrice': '$6.49', 'meta_code': -1, 'meta_entry': ''}
