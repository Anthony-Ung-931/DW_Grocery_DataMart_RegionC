# %% [markdown]
# ## Product Mapping
# ### Anthony Ung

# %%
import csv
import re

products_old = []
products_mapped = []
new_product_classes = []

# Read the product and product classes files.
with open('Products1.txt', 'r') as csvfile:

    csv.register_dialect('piper', delimiter='|', quoting=csv.QUOTE_NONE)
    for row in csv.DictReader(csvfile, dialect='piper'):
        products_old.append(row)

    with open('product_class.txt', 'r') as csvfile:
        csv.register_dialect('tab', delimiter='\t', quoting=csv.QUOTE_NONE)
        
        for row in csv.DictReader(csvfile, dialect='tab'):
            new_product_classes.append(row)

def pipeline(src, dst1, dst2, func):
    func(src, dst1, dst2)

# ETL 1: Change all the manufacturers to either 'Rowan Warehouse' or 'Rowan Dairy'
def etl_1(src, dst1, dst2=None):
    for product in src:
        if product['itemType'] == 'Milk':
            product['Supplier'] = 'Rowan Dairy'
        else:
            product['Supplier'] = 'Rowan Warehouse'
    
        dst1.append(product)


# ETL 2: Handle the 1319 products that can directly be mapped to one of the subcategories
def etl_2(src, dst1, dst2):
    product_classes = {}
    
    for p_entry in new_product_classes:
        product_classes[p_entry['product_subcategory']] = int(p_entry['product_class_id'])
    
    for product in src:
        if product['itemType'] in product_classes.keys():
            product['itemCode'] = product_classes[p_entry['product_subcategory']]
            product['meta_code'] = 1
            product['meta_entry'] = 'Mapped by AU from old Item type into new subcategory'
            dst1.append(product)
        else:
            product['meta_code'] = -1
            product['meta_entry'] = ''
            dst2.append(product)


# ETL 3 - Bagel
def etl_3(src, dst1, dst2):
    product_classes = []
    
    for p_entry in new_product_classes:
        product_classes.append(p_entry['product_subcategory'])

    pattern = 'Bagel'
    
    for product in src:
        if re.search(pattern, product['Product Name']):
            product['itemCode'] = 25
            product['meta_code'] = 2
            product['meta_entry'] = 'Mapped by AU from character match with Bagel'
            dst1.append(product)
        else:
            dst2.append(product)


# ETL 4 - Bread
def etl_4(src, dst1, dst2):
    for product in src:
        if product['itemType'] != 'Bread':
            dst2.append(product)
        else:
            pattern_1 = 'Cheeseburger'
            pattern_2 = 'Chicken'
            pattern_3 = 'Texas Toast'
            
            if re.search(pattern_1, product['Product Name']) \
                or re.search(pattern_2, product['Product Name']) \
                or re.search(pattern_3, product['Product Name']):
            
                dst2.append(product)

            else:
                product['itemCode'] = 27
                product['meta_code'] = 3
                product['meta_entry'] = 'Mapped by AU with a character match for Bread ' \
                                            'and assuming all these matches are sliced'
                dst1.append(product)


# ETL 5 - Snacks
def etl_5(src, dst1, dst2):
    for product in src:
        pattern_1 = 'Dip '

        if re.search(pattern_1, product['Product Name']):
            product['itemCode'] = 83
            product['meta_code'] = 4
            product['meta_entry'] = 'Mapped by AU with a character match for Dips'
            dst1.append(product)
            continue

        pattern_2 = 'Doritos'
        if re.search(pattern_2, product['Product Name']):
            product['itemCode'] = 12
            product['meta_code'] = 5
            product['meta_entry'] = 'Mapped by AU with a character match for Doritos'
            dst1.append(product)
            continue

        pattern_3 = 'Ruffles'
        if re.search(pattern_3, product['Product Name']):
            product['itemCode'] = 12
            product['meta_code'] = 6
            product['meta_entry'] = 'Mapped by AU with a character match for Chips'
            dst1.append(product)
            continue

        pattern_4 = 'Lays'
        if re.search(pattern_4, product['Product Name']):
            product['itemCode'] = 12
            product['meta_code'] = 7
            product['meta_entry'] = 'Mapped by AU with a character match for Lays'
            dst1.append(product)
            continue

        pattern_5 = 'Tostitos'
        pattern_6 = 'Salsa'
        if ((re.search(pattern_5, product['Product Name'])) and (not (re.search(pattern_6, product['Product Name'])))):
            product['itemCode'] = 12
            product['meta_code'] = 8
            product['meta_entry'] = 'Mapped by AU with a character match for Tostitos and ignoring Salsa'
            dst1.append(product)
            continue

        pattern_7 = 'Crisps'
        if re.search(pattern_7, product['Product Name']):
            product['itemCode'] = 12
            product['meta_code'] = 9
            product['meta_entry'] = 'Mapped by AU with a character match for Crisps'
            dst1.append(product)
            continue

        pattern_8 = 'Salsa'
        if re.search(pattern_8, product['Product Name']):
            product['itemCode'] = 83
            product['meta_code'] = 10
            product['meta_entry'] = 'Mapped by AU with a character match for Salsa'
            dst1.append(product)
            continue

        dst2.append(product)


# ETL 6 - Coffee
def etl_6(src, dst1, dst2):
    for product in src:
        pattern_1 = 'Coffee'
        pattern_2 = 'Cake'
        pattern_3 = 'Coffeemate'
        pattern_4 = 'Creamer'

        if re.search(pattern_1, product['Product Name']) \
            and (not re.search(pattern_2, product['Product Name'])) \
            and (not re.search(pattern_3, product['Product Name'])) \
            and (not re.search(pattern_4, product['Product Name'])):
        
            product['itemCode'] = 7
            product['meta_code'] = 11
            product['meta_entry'] = 'Mapped by AU with a character match for Coffee'
            dst1.append(product)
            continue
            
        dst2.append(product)


# ETL 7 - Donuts
def etl_7(src, dst1, dst2):
    for product in src:
        pattern_1 = 'Donut'

        if re.search(pattern_1, product['Product Name']):          
            product['itemCode'] = 84
            product['meta_code'] = 12
            product['meta_entry'] = 'Mapped by AU with a character match for Donuts'
            dst1.append(product)
            continue
            
        dst2.append(product)


# ETL 8 - Hamburger Helper
def etl_8(src, dst1, dst2):
    for product in src:
        pattern_1 = 'Hamburger Helper'

        if re.search(pattern_1, product['Product Name']):
            product['itemCode'] = 4
            product['meta_code'] = 13
            product['meta_entry'] = 'Mapped by AU with a character match for Hamburger Helper'
            dst1.append(product)
            continue
            
        dst2.append(product)


# ETL 9 - Pasta
def etl_9(src, dst1, dst2):
    for product in src:
        pattern_1 = 'Sauce'

        # "Lasagna With Meat And Sauce Pasta" should be frozen
        pattern_2 = 'Lasagna With Meat And Sauce Pasta'

        if re.search(pattern_1, product['Product Name']) \
            and (not re.search(pattern_2, product['Product Name'])):
            
            product['itemCode'] = 48
            product['meta_code'] = 14
            product['meta_entry'] = 'Mapped by AU with a character match for Sauce'
            dst1.append(product)
            continue
            
        dst2.append(product)


# ETL 10 - Goldfish
def etl_10(src, dst1, dst2):
    for product in src:
        pattern_1 = 'Goldfish'

        if re.search(pattern_1, product['Product Name']):
            product['itemCode'] = 82
            product['meta_code'] = 15
            product['meta_entry'] = 'Mapped by AU with a character match for Goldfish and mapping to crackers'
            dst1.append(product)
            continue

        pattern_2 = 'Chips Ahoy'

        if re.search(pattern_2, product['Product Name']):          
            product['itemCode'] = 45
            product['meta_code'] = 16
            product['meta_entry'] = 'Mapped by AU with a character match for Goldfish and mapping to crackers'
            dst1.append(product)
            continue

        pattern_3 = 'Wheat Thins'

        if re.search(pattern_3, product['Product Name']):
            product['itemCode'] = 82
            product['meta_code'] = 17
            product['meta_entry'] = 'Mapped by AU with a character match for Wheat Thins and mapping to crackers'
            dst1.append(product)
            continue
            
        dst2.append(product)


# ETL 11 - Specific Manufacturer
def etl_11(src, dst1, dst2):
    for product in src:
        pattern_1 = 'Tastykake'

        if re.search(pattern_1, product['Manufacturer']):
            product['itemCode'] = 84
            product['meta_code'] = 18
            product['meta_entry'] = 'Mapped by AU by TastyKake Manufacturer. Made decision that all Tastykake products are donuts'
            dst1.append(product)
            continue

        pattern_2 = 'Welchs'

        if re.search(pattern_1, product['Manufacturer']):
            product['itemCode'] = 30
            product['meta_code'] = 18
            product['meta_entry'] = 'Mapped by AU by Welchs Manufacturer'
            dst1.append(product)
            continue
            
        dst2.append(product)

# ETL 1: Change all the manufacturers to either 'Rowan Warehouse' or 'Rowan Dairy'
products_etl_1 = []
pipeline(products_old, products_etl_1, None, etl_1)


# ETL 2: Handle the 1319 products that can directly be mapped to one of the subcategories
products_etl_to_be_mapped_v1 = []
pipeline(products_etl_1, products_mapped, products_etl_to_be_mapped_v1, etl_2)


# ETL 3: Bagels
products_etl_to_be_mapped_v2 = []
pipeline(products_etl_to_be_mapped_v1, products_mapped, products_etl_to_be_mapped_v2, etl_3)


# ETL 4: Bread
products_etl_to_be_mapped_v3 = []
pipeline(products_etl_to_be_mapped_v2, products_mapped, products_etl_to_be_mapped_v3, etl_4)


# ETL 5: Snacks
products_etl_to_be_mapped_v4 = []
pipeline(products_etl_to_be_mapped_v3, products_mapped, products_etl_to_be_mapped_v4, etl_5)


# ETL 6: Coffee - Make this one earlier next time
products_etl_to_be_mapped_v5 = []
pipeline(products_etl_to_be_mapped_v4, products_mapped, products_etl_to_be_mapped_v5, etl_6)


# ETL 7: Donuts
products_etl_to_be_mapped_v6 = []
pipeline(products_etl_to_be_mapped_v5, products_mapped, products_etl_to_be_mapped_v6, etl_7)


# ETL 8: Hamburger Helper - Needs to be before Pasta
products_etl_to_be_mapped_v7 = []
pipeline(products_etl_to_be_mapped_v6, products_mapped, products_etl_to_be_mapped_v7, etl_8)


# ETL 9: Pasta
products_etl_to_be_mapped_v8 = []
pipeline(products_etl_to_be_mapped_v7, products_mapped, products_etl_to_be_mapped_v8, etl_9)


# ETL 10: Goldfish and other Snacks
products_etl_to_be_mapped_v9 = []
pipeline(products_etl_to_be_mapped_v8, products_mapped, products_etl_to_be_mapped_v9, etl_10)


# ETL 11: TastyKake
products_etl_to_be_mapped_v10 = []
pipeline(products_etl_to_be_mapped_v9, products_mapped, products_etl_to_be_mapped_v10, etl_11)


print(len(products_etl_to_be_mapped_v10))
print('Done')
# Out:
# 430
# Done

# %%
for product in products_etl_to_be_mapped_v9:
    print(product['Product Name'])
# Out:
# Jambalaya Rice Mix
# Jambalaya Rice Mix
# Guacamole Regular
# Italian Dressing
# Cheeseburger Heat & Serve Sliders
# Farmers Pick Concord Grape
# Shells & Cheese Microwave Cup
# Shells & Cheese Original
# Iced Tea Lemon
# English Muffins Double Fiber Honey Wheat
# English Muffins Hearty Grains 100% Whole Wheat
# English Muffins Multi Grain Light
# English Muffins Original
# English Muffins Original
# English Muffins Original Whole Grain With Omega 3
# English Muffins Raisin
# English Muffins Triple Health
# Cake Dreamies Creme Kakes
# Cake Kandy Kake Peanut Butter
# Cake Koffee Kake Cream Filled
# Cupcakes Buttercream
# Cupcakes Chocolate
# Cupcakes Krimpet Butterscotch
# Cupcakes Lemon
# Pie Apple
# Pie Cherry
# Pie Chocolate Klair
# Pie Lemon
# Pie Peach
# Hot Cocoa Mix Marshmallows
# Hot Cocoa Mix Milk Chocolate
# Hot Cocoa Mix Milk Chocolate Canister
# Hot Cocoa Mix Milk Chocolate No Sugar Added
# Sunny Delight Original
# Orange Citrus Punch Smooth
# Orange Citrus Punch Tangy Original
# Stuffing Mix Pork
# Lasagna With Meat And Sauce Pasta
# Sandwich Steaks Thin Sliced
# Chunk Light Tuna Water (pouch)
# Hot Cocoa Mix Premium Double Chocolate
# Hot Cocoa Mix Salted Caramel
# Hot Cocoa Mix Vanilla Brulee
# Vinegar Balsamic
# Sparkling Spring Water Pomegranate Berry
# Soy Milk Vanilla
# Baby Lotion Original
# Hair Moist Creme
# Hair Moisturizer Detangling
# Tortilla Chips Original
# Singles To Go Diet Green Tea
# Singles To Go Diet Lemon
# Jam Grape
# Jam Strawberry
# Jelly Grape
# Squeeze Jelly Grape
# Almond Milk Original
# Soymilk Light Chocolate
# All Purpose Cleaner Bleach 5-in-1
# Shower Automatic Refill Liquid Shower Cleaner
# Sponges Blue
# English Muffins Original
# Tastings Medium Asiago
# Tastings Parmentino
# Flatbread Angus Cheeseburgers
# Flatbread Chicken Melts
# Bread Texas Toast
# Juice Just Black Cherry
# Sugar White
# Honey Wheat Rods Pretzels
# Peanut Butter Cups King Size
# Stone Wheat Thins Original
# Just Black Cherry Juice
# Apple Nut Harvest Real Medley Bars
# Cherry Pistachio Real Medley Bars
# Granola Bars Chewy Chocolate Chip
# Peach Almond Real Medley Bars
# Yogurt Strawberry Chewy Granola Bars
# Sausage Pork
# Lettuce Head
# Turnip Greens Vegetables
# BBQ Grab & Go
# Cheddar Cheese Grab & Go
# Honey Butter Stix
# Mixed Flavors Snack Stacks
# Original Fat Free Potato Chips
# Original Grab & Go
# Pizza Stix
# Sour Cream & Onion Grab & Go
# Sour Cream & Onion Stacks
# Variety Pack Grab & Go
# Zero Fruit Punch
# Zero Grape
# Zero Mixed Berry
# Zero Orange
# Grands Biscuits Buttermilk
# Grands Biscuits Flaky Layers Buttermilk
# Grands Biscuits Southern Homestyle Buttermilk
# Grands Biscuits Southern Homestyle Buttermilk
# Grands Junior Biscuits Flaky Layers Buttermilk
# Hamburgers Pure Beef
# Hamburgers Pure Beef
# Evaporated Milk Original
# Jewish Rye Seeded
# Stuffing Corn Bread
# Texas Toast 5 Cheese
# Texas Toast Garlic
# Chopped Beef Dog Food
# Cough & Congestion Cherry
# Pasta Butter And Garlic
# Dutch Style Hot Cocoa Mix
# Oxy Blue
# Oxi Clean Laundry Detergent
# Drink Mix Chocolate Malt
# Drink Mix Chocolate Malt
# Drink Mix Rich Chocolate
# Hot Dogs Regular
# Hot Dogs Turkey Smoked
# Microwave Popcorn Butter
# Popcorn Garlic Butter & Sea Salt
# Blueberries In Light Syrup
# French Fries Shoestring
# Meatballs Angus Beef
# Chicken Patties
# Juice Blueberry Pomegranate
# Juice Peach Mango
# Taco Seasoning Original
# Craisins Original
# Juice Cherry
# Juice Citrus Tangerine Orange Juice
# Juice Grape Cranberry
# Juice White Grapefruit
# Sparkling Juice Cranberry
# Spread Hazelnut
# Carnation Reduced Fat
# Coffeemate French Vanilla
# Hot Cocoa Mix Milk Chocolate
# Hot Cocoa Mix Mini Marshmallow
# Milk Banana Strawberry
# Tea Instant
# Drink Mix Chocolate
# Drink Mix Chocolate
# Drink Mix Chocolate
# Wheat Thins Big Crackers Original
# Wheat Thins Cracked Pepper & Olive Oil
# Wheat Thins Hint Of Salt
# Wheat Thins Original
# Wheat Thins Ranch
# Wheat Thins Reduced Fat
# Wheat Thins Sundried Tomato & Basil
# Wheat Thins Toasted Chips Multigrain
# Wheat Thins Toasted Chips Veggie
# Wheat Thins Toasted Pita Garlic Herb
# Wheat Thins Toasted Pita Original
# Syrup Regular
# Juice Boxes Apple White Grape
# Applesauce Cinnamon
# Pain Reliever/Fever Reducer Original Berry
# Salt Kosher
# Sea Salt Coarse
# Sea Salt Fine
# Coolers Fruit Punch
# Fruit Drink Peach
# Juice Cherry Limeade
# Orange Juice No Pulp
# Vanilla, Butter & Nut Exctract
# Rice Brown
# Rice Jasmine
# Rice White
# Gas Relief Drops Natural Berry
# Spray & Drops Saline
# Bars Marshmallow Treat
# Bars Nutty
# Brownies Cosmic
# Brownies Fudge
# Buns Honey
# Cake Cloud Cakes
# Cake Swiss Rolls
# Cake Zebra Cakes
# Cookies Oatmeal Cream Pies
# Cookies Oatmeal Cream Pies
# Cupcakes Chocolate
# Muffins Banana Nut
# Muffins Blueberry
# Pie Marshmallow Chocolate
# Spin Wheels Pecan
# Mint Shield Mouthwash
# Tea Bags Black Tea & Honey Berry Lemonade Decaf
# Tea Bags Green Tea & Honey Coconut Passionfruit
# Tea Bags Green Tea & Honey Dragonfruit Peach
# Tea Stix Tea & Honey Lemon
# Ham & Cheese Whole Grain Crust
# Lean Cusine Frozen
# Bread Crumbs Italian Style
# Eggs Large
# Eggs Large
# Twisted Bread Sticks Garlic
# Twisted Bread Sticks Mozzarella
# American Singles 2% Milk
# Cool Whip Regular
# Deluxe Mac & Cheese Four Cheese
# Mac & Cheese Southwest Chipotle
# Salad Dressing Italian
# Salad Dressing Ranch
# Salad Dressing Thousand Island
# Salad Dressing Zesty Italian
# Bursts Cherry
# Jammers Cherry
# Oven Cravers Cordon Bleu
# Cooking Stock Chicken
# Flour All Purpose
# Salad Dressing French
# Salad Dressing Italian
# Salad Dressing Ranch
# Salad Dressing Thousand Island
# Eggo Breakfast Sandwiches Bacon Egg & Cheese
# Eggo French Toaster Sticks Cinnamon
# Eggo Pancakes Buttermilk
# Eggo Pancakes Chocolatey Chip Bites
# Eggo Pancakes Minis
# Eggo Wafflers Brown Sugar Cinnamon
# Eggo Waffles Blueberry
# Eggo Waffles Buttermilk
# Eggo Waffles Chocolatey Chip
# Eggo Waffles Cinnamon Toast Mini
# Eggo Waffles Gluten Free Original
# Eggo Waffles Homestyle
# Eggo Waffles Homestyle
# Eggo Waffles Homestyle Mini
# Eggo Waffles Nutri-Grain Blueberry
# Eggo Waffles Nutri-Grain Low Fat
# Eggo Waffles Nutri-Grain Whole Wheat
# Eggo Waffles Oats & Mixed Berries
# Eggo Waffles Strawberry
# Eggo Waffles Thick & Fluffy Cinnamon Brown Sugar
# Eggo Waffles Thick & Fluffy Original
# Nutri Grain Blueberry Bliss Harvest Fruit & Oat Bars
# Nutri Grain Chocolatey Crunch Granola Bar
# Nutri Grain Fruit Crunch Apple Cobbler Granola Bars
# Nutri Grain Fruit Crunch Strawberry Parfait Granola Bars
# Nutri Grain Strawberry Vanilla Fruit Yogurt Bar
# Nutri Grain Toffee Crunch Bar
# Nutri-Grain Harvest Strawberry Fruit & Oat Bars
# Rice Krispies Treats Marshmallows Squares
# Special K Indulgent Moments Dreamy Coconut Snack Bites
# Special K Moments Caramel Pretzel Bliss Snack Bites
# Special K Protein Greek Yogurt & Fruit Snack Bar
# Nectar Guava
# Juice Boxes Apple
# Juice Orange Tangerine
# Baby Oil Original
# Baby Powder Original
# Baby Shampoo Original
# Cake Mix Yellow
# Mix Baking
# Mix Pizza Crust
# Muffin Mix Blueberry
# Muffin Mix Corn
# Muffin Mix Corn
# Muffin Mix Raspberry
# Muffin Mix Vegetarian Corn
# Sugar Free Coffee Creamer French Vanilla
# Mashed Potatoes Four Cheese
# Sour Cream Original
# Cake Coffee Cakes Multi Pack
# Cake Ding Dongs
# Cake Ho Hos
# Cake Twinkies
# Cake Twinkies
# Cupcakes Chocolate
# Pie Apple
# Juice Boxes Grabbin Grape
# Syrup Chocolate
# Syrup Strawberry
# Syrup Chocolate
# Syrup Chocolate
# Syrup Chocolate Lite
# Syrup Chocolate Sugar Free
# Syrup Strawberry
# Ketchup Original
# Aloha Morning Mixed Berry
# Aloha Morning Orange Citrus
# Juice Lemonade
# Coconut Milk Original
# Flavor Straws Chocolate
# Flavor Straws Strawberry Magic
# Cookies Chocolate
# Cookies Vanilla Creme Chocolate
# Vitamin Water Tropical Citrus
# PopCorners Sea Salt
# G2 Lime
# Gatorade Sports Drink
# Sports Drink Strawberry Lemonade
# Variety Pack Baked & Popped Mix
# Variety Pack Bold Mix
# Variety Pack Cheesy Mix
# Variety Pack Classic Mix
# Variety Pack Fiery Mix
# Variety Pack Flavor Mix
# Juice Orange Pineapple
# Orange Juice No Pulp
# Simply Homemade Bread Mix
# Simply Homemade Cornbread Mix
# Air Effects With Gain
# Buns Cinnamon Swirl
# Buns Super Cinnamons
# Cake All Butter French Crumb
# Cake Cheese Breakfast Buns
# Cake Chocolate Fudge
# Cake Coffee Cake Cheese Crumb
# Cake Coffee Cake Crumb
# Cake Gold With Chocolate Fudge Icing
# Cake Jumbo Glazed Honey Bun
# Cake Lemon Crunch
# Cake Lemon Loaf
# Cake Louisiana Crunch
# Cake Pound Cake
# Cake Wrapped Crumb Mini
# Cake Wrapped Pound Cake Mini
# Cookies Chocolate Chip
# Cookies Chocolate Chip Soft Baked
# Danish Cheese Twist
# Danish Cherry Cheese
# Danish Raspberry
# Danish Twist Raspberry
# Little Bites Fudge Brownie
# Little Bites Mini Banana Chocolate Chip
# Little Bites Mini Blueberry
# Little Bites Snickerdoodle Cinnamon Sugar
# Muffins Chocolate Chip Mini
# Pie Apple
# Puffs Apple
# Pie Key Lime
# Shortbread Cookies
# Coffee Cakes Cake
# Devil Dogs Cake
# Ring Dings Cake
# Yodels Cake
# Bananas Bunch
# Juice Orange Peach Mango
# Hearty Meals Beef Stew
# Baby Shampoo Original
# Diced Mango Fruit Cup
# Fruit Burst Squeezers Mixed Berry
# Pear Halves In 100% Juice
# 3D White Arctic Fresh
# Lasagna Pasta
# Lemonade Yellow
# Spread Original
# Rotel Diced Tomatoes& Green Chilies
# FF & LS Broth Chicken
# Disinfecting Wipes Lemon Fresh
# Ultra Liquid Bleach Mountain Fresh
# Snack Mix Chocolate Peanut
# Beefaroni Whole Grain
# Mini Bites Dinos & Meatballs
# Ravioli Beef
# Original Malted Milk Drink Mix
# Coastal Cooler Strawberry Banana
# Roarin Waters Berry Berry Juice
# SuperV Apple
# Potato Chips Snacks
# Chicken Noodle Low Sodium
# Cream Of Chicken Soup
# Cream Of Mushroom Soup
# Gravy Turkey
# Soup Cream Of Mushroom
# Spaghetti O's Plus Calcium
# Brown Sugar Hickory Baked Beans
# Country Style Baked Beans
# Country Style Baked Beans
# Homestyle Baked Beans
# Homestyle Baked Beans
# Honey Baked Beans
# Maple Cured Bacon Baked Baked Beans
# Maple Cured Bacon Baked Beans
# Original Baked Beans
# Original Baked Beans
# Original Baked Beans
# Original Baked Beans
# Vegetarian Baked Beans
# Vegetarian Baked Beans
# Vegetarian Baked Beans
# Certified Angus Beef Burger
# Juice Grape
# Condensed Milk Sweetened
# Fruit & Vegetable Juice Mango Ginger
# Citrus Drop Soda
# Cola Regular
# Fruit Snacks SpongeBob
# Collezione Bucatini
# Gluten Free Elbows
# Gluten Free Penne
# Gluten Free Spaghetti
# Pasta Angel Hair
# Pasta Elbows
# Pasta Farfalle
# Pasta Fettuccine
# Pasta Fideo Cut Spaghetti
# Pasta Jumbo Shells
# Pasta Linguine
# Pasta Mini Penne
# Pasta Mostaccioli
# Pasta Orzo
# Pasta Penne
# Pasta Rigatoni
# Pasta Rotini
# Pasta Spaghetti
# Pasta Thick Spaghetti
# Pasta Thin Spaghetti
# Pasta Tri-Color Rotini
# Pasta Veggie Rotini
# Pasta Wavy Lasagne
# PLUS Multigrain Elbows
# Pronto Elbows
# Pronto Penne
# Pronto Rotini
# Pronto Spaghetti
# Protein Plus Multigrain Angel Hair
# Protein Plus Multigrain Penne
# Protein Plus Multigrain Thin Spaghetti
# White Fiber Shells
# White Fiber Spaghetti
# Whole Grain Lasagne
# Whole Grain Linguine
# Whole Grain Penne
# Whole Grain Rotini
# Whole Grain Spaghetti
# Whole Grain Thin Spaghetti
# Chicken Breast Stuffed Broccoli & Cheese
# Brown N Serve Sausage Maple Links
# Brown N Serve Sausage Original Links
# Brown N Serve Sausage Turkey
# Chicken Breast Strips
# Chicken Patties
# Chicken Patty
# Scramble Bacon
# Scramble Farmhouse-Style Sausage
# Coconut Milk Lite
# Fruitables Berry Berry Juice
# Drink Mix Spiced Cider
# Almond Milk Original
# Almond Milk Unsweetened
# Almond Milk Vanilla
# Snack Cakes Vanilla
# Laundry Detergent 2X Ultra Free Clear
# Gourmet Griller Carmelized Onion
# Gourmet Griller Sweet Italian
# Meatballs Caramelized Onion
# Meatballs Pineapple Teriyaki
# Meatballs Sundried Tomato
# Popcorn Butter
# Coconut Milk Unsweetened
# Iced Tea Mix Regular
